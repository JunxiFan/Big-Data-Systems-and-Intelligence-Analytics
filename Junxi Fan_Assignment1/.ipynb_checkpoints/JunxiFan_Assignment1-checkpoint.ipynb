# %% [markdown]
# # Part A

# %% [markdown]
# # Read Dataset

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
from sklearn.datasets import load_boston

# Make plots larger
plt.rcParams['figure.figsize'] = (15, 9)

# %%
data = pd.read_csv("./wfp_market_food_prices.csv", sep=',')
data.head(n=7)
# Out:
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id cm_name  \
# 0        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 1        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 2        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 3        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 4        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 5        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 6        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
#
#    cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  mp_year  mp_price  \
# 0      87      AFN     15  Retail      5      KG         1     2014      50.0
# 1      87      AFN     15  Retail      5      KG         2     2014      50.0
# 2      87      AFN     15  Retail      5      KG         3     2014      50.0
# 3      87      AFN     15  Retail      5      KG         4     2014      50.0
# 4      87      AFN     15  Retail      5      KG         5     2014      50.0
# 5      87      AFN     15  Retail      5      KG         6     2014      50.0
# 6      87      AFN     15  Retail      5      KG         7     2014      50.0
#
#   mp_commoditysource
# 0                WFP
# 1                WFP
# 2                WFP
# 3                WFP
# 4                WFP
# 5                WFP
# 6                WFP

# %% [markdown]
# # Meanings of Each Column

# %% [markdown]
# * adm0_id: country id
# * adm0_name: country name
# * adm1_id: locality id
# * adm1_name: locality name
# * mkt_id: market id
# * mkt_name: market name
# * cm_id: commodity purchase id
# * cm_name: commodity purchased
# * cur_id: currency id
# * cur_name: name of currency
# * pt_id: market type id
# * pt_name: market type (Retail/Wholesale/Producer/Farm Gate)
# * um_id: measurement id
# * um_name: unit of goods measurement
# * mp_month: month recorded
# * mp_year: year recorded
# * mp_price: price paid
# * mp_commoditysource: Source supplying price information

# %% [markdown]
# ----------------------------------
# ## I. Data Cleaning

# %% [markdown]
# **Pose a question: How to know food prices situation in a country by analyzing the dataset?**

# %% [markdown]
# ### 1. Check Missing Values

# %%
data.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# adm0_id                   0
# adm0_name                 0
# adm1_id                   0
# adm1_name             13949
# mkt_id                    0
# mkt_name                  0
# cm_id                     0
# cm_name                   0
# cur_id                    0
# cur_name                  0
# pt_id                     0
# pt_name                   0
# um_id                     0
# um_name                   0
# mp_month                  0
# mp_year                   0
# mp_price                  0
# mp_commoditysource        0
# dtype: int64

# %%
# data backup
data_bak = data.copy()

# %%
#drop rows with missing values
data_bak.dropna(inplace=True)

# %%
# check if row with missing value has been removed
data_bak.isnull().sum()
# Out:
# adm0_id               0
# adm0_name             0
# adm1_id               0
# adm1_name             0
# mkt_id                0
# mkt_name              0
# cm_id                 0
# cm_name               0
# cur_id                0
# cur_name              0
# pt_id                 0
# pt_name               0
# um_id                 0
# um_name               0
# mp_month              0
# mp_year               0
# mp_price              0
# mp_commoditysource    0
# dtype: int64

# %% [markdown]
# ### 2. Check  inappropraite values in the dataset

# %%
data_bak.describe()
# Out:
#              adm0_id        adm1_id         mkt_id          cm_id  \
# count  729965.000000  729965.000000  729965.000000  729965.000000
# mean      860.524409   18005.919580     888.111248     160.927520
# std      6379.306857   82078.325302     540.712015     117.931311
# min         1.000000     272.000000      80.000000      50.000000
# 25%       115.000000    1577.000000     380.000000      67.000000
# 50%       170.000000    2208.000000     911.000000     110.000000
# 75%       205.000000   21969.000000    1134.000000     233.000000
# max     70001.000000  900022.000000    2094.000000     490.000000
#
#               cur_id          pt_id          um_id       mp_month  \
# count  729965.000000  729965.000000  729965.000000  729965.000000
# mean       57.259937      14.930860      10.500401       6.378896
# std        23.135316       0.277758      13.126298       3.434346
# min        22.000000      14.000000       5.000000       1.000000
# 25%        29.000000      15.000000       5.000000       3.000000
# 50%        63.000000      15.000000       5.000000       6.000000
# 75%        77.000000      15.000000       5.000000       9.000000
# max        95.000000      18.000000     100.000000      12.000000
#
#              mp_year      mp_price
# count  729965.000000  7.299650e+05
# mean     2012.507628  4.234829e+03
# std         3.675369  5.600542e+04
# min      1992.000000  0.000000e+00
# 25%      2011.000000  3.100000e+01
# 50%      2013.000000  1.778750e+02
# 75%      2015.000000  5.062000e+02
# max      2017.000000  5.833333e+06

# %%
# get amounts of rows of different country
data_bak['adm0_name'].value_counts()
# Out:
# Rwanda                              115037
# India                                65864
# Niger                                36195
# Mali                                 32702
# Democratic Republic of the Congo     29997
# Zambia                               26374
# Ukraine                              24766
# Senegal                              22783
# Mozambique                           22652
# Gambia                               21575
# Syrian Arab Republic                 21310
# Tajikistan                           19679
# Kyrgyzstan                           18466
# Philippines                          18115
# Lebanon                              15942
# Lao People's Democratic Republic     15436
# Malawi                               15104
# Myanmar                              14601
# Nigeria                              10406
# Ethiopia                              9604
# Yemen                                 9105
# Burkina Faso                          8783
# Colombia                              8296
# Ghana                                 8112
# United Republic of Tanzania           7457
# Madagascar                            6437
# State of Palestine                    5952
# El Salvador                           5915
# Liberia                               5832
# Armenia                               5778
#                                      ...
# Afghanistan                           4676
# South Sudan                           4659
# Cote d'Ivoire                         4641
# Sudan                                 4447
# Bolivia                               4447
# Pakistan                              4307
# Cambodia                              3960
# Burundi                               3847
# Kenya                                 3639
# Benin                                 3452
# Uganda                                3236
# Chad                                  3170
# Bangladesh                            3035
# Sri Lanka                             2802
# Djibouti                              2791
# Congo                                 2420
# Zimbabwe                              2222
# Guinea                                2183
# Iraq                                  1987
# Algeria                               1784
# Somalia                               1677
# Timor-Leste                           1367
# Guinea-Bissau                         1293
# Jordan                                 972
# Central African Republic               963
# Peru                                   883
# Guatemala                              771
# Iran  (Islamic Republic of)            305
# Cape Verde                             276
# Georgia                                 80
# Name: adm0_name, Length: 65, dtype: int64

# %% [markdown]
# So, if we want to know more details about **Rwanda**:

# %%
#get data about Rwanda
data_Rwanda = data_bak.loc[data_bak['adm0_name'] == 'Rwanda']
#get amounts of different food in Rwanda
data_Rwanda['cm_name'].value_counts()
# Out:
# Beans (dry)                   4357
# Sweet potatoes                4353
# Maize flour                   4330
# Potatoes (Irish)              4320
# Cassava flour                 4275
# Sorghum                       4099
# Maize                         4024
# Passion fruit                 4014
# Bananas                       3691
# Eggplants                     3597
# Peppers (green)               3168
# Sorghum flour                 3080
# Cassava                       2766
# Charcoal                      2759
# Meat (beef)                   2624
# Rice                          2563
# Papaya                        2248
# Avocados                      2213
# Wheat flour                   2187
# Cabbage                       2148
# Onions (red)                  2147
# Tomatoes                      2147
# Carrots                       2114
# Mangoes                       2113
# Livestock (Goat)              2112
# Eggs                          2077
# Rice (imported, Indian)       1995
# Groundnuts (shelled)          1976
# Rice (imported, Tanzanian)    1972
# Chili (red)                   1938
# Livestock (hen)               1922
# Peas (fresh)                  1893
# Soybeans                      1892
# Garlic                        1867
# Milk                          1861
# Oranges (big size)            1843
# Cassava leaves                1599
# Zucchini                      1496
# Livestock (Sheep)             1421
# Wheat                         1336
# Spinach                       1320
# Beans (green, fresh)          1248
# Peas (dry)                    1235
# Meat (goat)                   1197
# Rice (local)                  1091
# Onions (white)                 923
# Cucumbers (greenhouse)         681
# Apples (red)                   599
# Cauliflower                    530
# Guava                          524
# Meat (pork)                    299
# Livestock (pig)                280
# Maize flour (imported)         233
# Livestock (cattle)             223
# Meat (mutton)                  117
# Name: cm_name, dtype: int64

# %% [markdown]
# Then, for example, we want to know more about banana's price:

# %%
# get data which related to 'Maize'
data_Bananas_Rwanda = data_Rwanda.loc[data_Rwanda['cm_name'] == 'Bananas']
data_Bananas_Rwanda
# Out:
#         adm0_id adm0_name  adm1_id             adm1_name  mkt_id mkt_name  \
# 467194      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467195      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467196      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467197      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467198      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467199      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467200      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467201      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467202      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467203      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467204      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467205      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467206      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467207      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467208      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467209      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467210      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467211      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467212      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467213      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467214      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467215      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467216      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467217      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467218      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467219      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467220      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467221      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467222      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467223      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# ...         ...       ...      ...                   ...     ...      ...
# 580743      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580744      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580745      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580746      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580747      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580748      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580749      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580750      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580751      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580752      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580753      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580754      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580755      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580756      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580757      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580758      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580759      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580760      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580761      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580762      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580763      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580764      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580765      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580766      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580767      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580768      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580769      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580770      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580771      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580772      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
#
#         cm_id  cm_name  cur_id cur_name  pt_id pt_name  um_id um_name  \
# 467194    254  Bananas      77      RWF     15  Retail      5      KG
# 467195    254  Bananas      77      RWF     15  Retail      5      KG
# 467196    254  Bananas      77      RWF     15  Retail      5      KG
# 467197    254  Bananas      77      RWF     15  Retail      5      KG
# 467198    254  Bananas      77      RWF     15  Retail      5      KG
# 467199    254  Bananas      77      RWF     15  Retail      5      KG
# 467200    254  Bananas      77      RWF     15  Retail      5      KG
# 467201    254  Bananas      77      RWF     15  Retail      5      KG
# 467202    254  Bananas      77      RWF     15  Retail      5      KG
# 467203    254  Bananas      77      RWF     15  Retail      5      KG
# 467204    254  Bananas      77      RWF     15  Retail      5      KG
# 467205    254  Bananas      77      RWF     15  Retail      5      KG
# 467206    254  Bananas      77      RWF     15  Retail      5      KG
# 467207    254  Bananas      77      RWF     15  Retail      5      KG
# 467208    254  Bananas      77      RWF     15  Retail      5      KG
# 467209    254  Bananas      77      RWF     15  Retail      5      KG
# 467210    254  Bananas      77      RWF     15  Retail      5      KG
# 467211    254  Bananas      77      RWF     15  Retail      5      KG
# 467212    254  Bananas      77      RWF     15  Retail      5      KG
# 467213    254  Bananas      77      RWF     15  Retail      5      KG
# 467214    254  Bananas      77      RWF     15  Retail      5      KG
# 467215    254  Bananas      77      RWF     15  Retail      5      KG
# 467216    254  Bananas      77      RWF     15  Retail      5      KG
# 467217    254  Bananas      77      RWF     15  Retail      5      KG
# 467218    254  Bananas      77      RWF     15  Retail      5      KG
# 467219    254  Bananas      77      RWF     15  Retail      5      KG
# 467220    254  Bananas      77      RWF     15  Retail      5      KG
# 467221    254  Bananas      77      RWF     15  Retail      5      KG
# 467222    254  Bananas      77      RWF     15  Retail      5      KG
# 467223    254  Bananas      77      RWF     15  Retail      5      KG
# ...       ...      ...     ...      ...    ...     ...    ...     ...
# 580743    254  Bananas      77      RWF     15  Retail      5      KG
# 580744    254  Bananas      77      RWF     15  Retail      5      KG
# 580745    254  Bananas      77      RWF     15  Retail      5      KG
# 580746    254  Bananas      77      RWF     15  Retail      5      KG
# 580747    254  Bananas      77      RWF     15  Retail      5      KG
# 580748    254  Bananas      77      RWF     15  Retail      5      KG
# 580749    254  Bananas      77      RWF     15  Retail      5      KG
# 580750    254  Bananas      77      RWF     15  Retail      5      KG
# 580751    254  Bananas      77      RWF     15  Retail      5      KG
# 580752    254  Bananas      77      RWF     15  Retail      5      KG
# 580753    254  Bananas      77      RWF     15  Retail      5      KG
# 580754    254  Bananas      77      RWF     15  Retail      5      KG
# 580755    254  Bananas      77      RWF     15  Retail      5      KG
# 580756    254  Bananas      77      RWF     15  Retail      5      KG
# 580757    254  Bananas      77      RWF     15  Retail      5      KG
# 580758    254  Bananas      77      RWF     15  Retail      5      KG
# 580759    254  Bananas      77      RWF     15  Retail      5      KG
# 580760    254  Bananas      77      RWF     15  Retail      5      KG
# 580761    254  Bananas      77      RWF     15  Retail      5      KG
# 580762    254  Bananas      77      RWF     15  Retail      5      KG
# 580763    254  Bananas      77      RWF     15  Retail      5      KG
# 580764    254  Bananas      77      RWF     15  Retail      5      KG
# 580765    254  Bananas      77      RWF     15  Retail      5      KG
# 580766    254  Bananas      77      RWF     15  Retail      5      KG
# 580767    254  Bananas      77      RWF     15  Retail      5      KG
# 580768    254  Bananas      77      RWF     15  Retail      5      KG
# 580769    254  Bananas      77      RWF     15  Retail      5      KG
# 580770    254  Bananas      77      RWF     15  Retail      5      KG
# 580771    254  Bananas      77      RWF     15  Retail      5      KG
# 580772    254  Bananas      77      RWF     15  Retail      5      KG
#
#         mp_month  mp_year  mp_price mp_commoditysource
# 467194        11     2010  199.5000            MINAGRI
# 467195        12     2010  216.0000            MINAGRI
# 467196         1     2011  168.0000            MINAGRI
# 467197         2     2011  178.0000            MINAGRI
# 467198         3     2011  127.8000            MINAGRI
# 467199         4     2011  114.0000            MINAGRI
# 467200         5     2011  127.6000            MINAGRI
# 467201         6     2011  170.0000            MINAGRI
# 467202         7     2011  140.5000            MINAGRI
# 467203         8     2011  148.8000            MINAGRI
# 467204         9     2011  148.0000            MINAGRI
# 467205        10     2011  136.2500            MINAGRI
# 467206        11     2011  141.6000            MINAGRI
# 467207        12     2011  150.0000            MINAGRI
# 467208         1     2012  122.5000            MINAGRI
# 467209         2     2012  137.5000            MINAGRI
# 467210         3     2012  140.0000            MINAGRI
# 467211         4     2012  115.5000            MINAGRI
# 467212         5     2012  133.0000            MINAGRI
# 467213         6     2012  165.0000            MINAGRI
# 467214         7     2012  128.3333            MINAGRI
# 467215         8     2012  116.6667            MINAGRI
# 467216         9     2012  135.0000            MINAGRI
# 467217        10     2012  180.0000            MINAGRI
# 467218        11     2012  144.0000            MINAGRI
# 467219        12     2012  138.6667            MINAGRI
# 467220         1     2013  119.0000            MINAGRI
# 467221         2     2013  125.0000            MINAGRI
# 467222         3     2013  169.2500            MINAGRI
# 467223         4     2013  133.7500            MINAGRI
# ...          ...      ...       ...                ...
# 580743         7     2013  105.0000            MINAGRI
# 580744         8     2013  118.7500            MINAGRI
# 580745         9     2013  215.0000            MINAGRI
# 580746        10     2013  171.2500            MINAGRI
# 580747        11     2013  147.5000            MINAGRI
# 580748        12     2013  156.0000            MINAGRI
# 580749         1     2014  146.5000            MINAGRI
# 580750         2     2014  162.5000            MINAGRI
# 580751         3     2014  153.3333            MINAGRI
# 580752         4     2014  185.0000            MINAGRI
# 580753         5     2014  175.0000            MINAGRI
# 580754         6     2014  204.5000            MINAGRI
# 580755         7     2014  127.0000            MINAGRI
# 580756         8     2014  120.0000            MINAGRI
# 580757         9     2014  140.0000            MINAGRI
# 580758        10     2014  160.0000            MINAGRI
# 580759        11     2014  147.5000            MINAGRI
# 580760        12     2014  133.0000            MINAGRI
# 580761         1     2015  147.5000            MINAGRI
# 580762         2     2015  141.2500            MINAGRI
# 580763         3     2015  165.0000            MINAGRI
# 580764         4     2015  161.6667            MINAGRI
# 580765         5     2015  158.7500            MINAGRI
# 580766         6     2015  122.5000            MINAGRI
# 580767         7     2015  120.7500            MINAGRI
# 580768         8     2015  124.2000            MINAGRI
# 580769         9     2015  157.0000            MINAGRI
# 580770        10     2015  172.5000            MINAGRI
# 580771        11     2015  200.0000            MINAGRI
# 580772        12     2015  200.0000            MINAGRI
#
# [3691 rows x 18 columns]

# %% [markdown]
# -----------------------
# ## II. How is the data distributed?

# %%
# distribution of bananas' price per kg
sns.distplot(data_Bananas_Rwanda['mp_price'])

# %% [markdown]
# The distribution of bananas' price per kg looks like a Normal Distribution.

# %% [markdown]
# ## III. Summary statistics

# %%
data_Bananas_Rwanda.head()
# Out:
#         adm0_id adm0_name  adm1_id             adm1_name  mkt_id mkt_name  \
# 467194      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467195      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467196      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467197      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 467198      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
#
#         cm_id  cm_name  cur_id cur_name  pt_id pt_name  um_id um_name  \
# 467194    254  Bananas      77      RWF     15  Retail      5      KG
# 467195    254  Bananas      77      RWF     15  Retail      5      KG
# 467196    254  Bananas      77      RWF     15  Retail      5      KG
# 467197    254  Bananas      77      RWF     15  Retail      5      KG
# 467198    254  Bananas      77      RWF     15  Retail      5      KG
#
#         mp_month  mp_year  mp_price mp_commoditysource
# 467194        11     2010     199.5            MINAGRI
# 467195        12     2010     216.0            MINAGRI
# 467196         1     2011     168.0            MINAGRI
# 467197         2     2011     178.0            MINAGRI
# 467198         3     2011     127.8            MINAGRI

# %%
data_Bananas_Rwanda.describe()
# Out:
#        adm0_id       adm1_id       mkt_id   cm_id  cur_id   pt_id   um_id  \
# count   3691.0   3691.000000  3691.000000  3691.0  3691.0  3691.0  3691.0
# mean     205.0  20190.983202  1147.201842   254.0    77.0    15.0     5.0
# std        0.0   5599.092505   152.457890     0.0     0.0     0.0     0.0
# min      205.0   2587.000000  1045.000000   254.0    77.0    15.0     5.0
# 25%      205.0  21969.000000  1062.000000   254.0    77.0    15.0     5.0
# 50%      205.0  21971.000000  1085.000000   254.0    77.0    15.0     5.0
# 75%      205.0  21973.000000  1106.000000   254.0    77.0    15.0     5.0
# max      205.0  21973.000000  1562.000000   254.0    77.0    15.0     5.0
#
#           mp_month      mp_year     mp_price
# count  3691.000000  3691.000000  3691.000000
# mean      6.649688  2012.636413   202.659983
# std       3.437244     1.798680   109.944700
# min       1.000000  2008.000000    48.250000
# 25%       4.000000  2011.000000   135.000000
# 50%       7.000000  2013.000000   176.600000
# 75%      10.000000  2014.000000   212.250000
# max      12.000000  2015.000000  1708.500000

# %%
data_Bananas_Rwanda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3691 entries, 467194 to 580772
# Data columns (total 18 columns):
# adm0_id               3691 non-null int64
# adm0_name             3691 non-null object
# adm1_id               3691 non-null int64
# adm1_name             3691 non-null object
# mkt_id                3691 non-null int64
# mkt_name              3691 non-null object
# cm_id                 3691 non-null int64
# cm_name               3691 non-null object
# cur_id                3691 non-null int64
# cur_name              3691 non-null object
# pt_id                 3691 non-null int64
# pt_name               3691 non-null object
# um_id                 3691 non-null int64
# um_name               3691 non-null object
# mp_month              3691 non-null int64
# mp_year               3691 non-null int64
# mp_price              3691 non-null float64
# mp_commoditysource    3691 non-null object
# dtypes: float64(1), int64(9), object(8)
# memory usage: 547.9+ KB

# %%
data_Bananas_Rwanda.shape
# Out:
# (3691, 18)

# %%
data_Bananas_Rwanda.mp_price.value_counts()
# Out:
# 200.0000    361
# 150.0000     75
# 300.0000     60
# 100.0000     45
# 120.0000     44
# 250.0000     42
# 160.0000     37
# 180.0000     35
# 500.0000     32
# 165.0000     28
# 140.0000     27
# 400.0000     25
# 170.0000     23
# 195.0000     23
# 275.0000     23
# 190.0000     21
# 225.0000     20
# 350.0000     19
# 125.0000     19
# 130.0000     18
# 145.0000     17
# 175.0000     16
# 80.0000      16
# 110.0000     16
# 135.0000     15
# 155.0000     14
# 375.0000     14
# 115.0000     13
# 210.0000     13
# 325.0000     13
#            ...
# 171.4000      1
# 333.2000      1
# 344.8889      1
# 491.7500      1
# 437.2500      1
# 88.6000       1
# 137.7778      1
# 433.2000      1
# 223.6667      1
# 123.2000      1
# 128.4444      1
# 202.6000      1
# 201.2500      1
# 546.3333      1
# 435.5000      1
# 176.2500      1
# 675.0000      1
# 158.6250      1
# 199.7500      1
# 463.3333      1
# 242.8750      1
# 211.8000      1
# 288.6667      1
# 127.8571      1
# 98.3333       1
# 119.6000      1
# 198.9167      1
# 455.4000      1
# 221.4286      1
# 216.0000      1
# Name: mp_price, Length: 1418, dtype: int64

# %% [markdown]
# ## IV. Outliers

# %% [markdown]
# Use Box-Plot to find outliers.

# %%
sns.boxplot(x = "mp_year", y = "mp_price", data = data_Bananas_Rwanda)

# %% [markdown]
# There are outliers among 2009 to 2014

# %% [markdown]
# ## V. Plot

# %% [markdown]
# First, let's see the tendency of banana's price from 2008 to 2015.

# %%
sns.pointplot(x = "mp_year", y = "mp_price", data = data_Bananas_Rwanda)

# %%
sns.regplot(x = "mp_year", y = "mp_price", data = data_Bananas_Rwanda)

# %%
sns.lmplot(x = "mp_month", y = "mp_price", hue="mp_year", data = data_Bananas_Rwanda,size=10)

# %%
sns.barplot(x = "mp_year", y = "mp_price", hue = "mp_month", data = data_Bananas_Rwanda)

# %%
# get data in 2008 
data_Bananas_Rwanda.loc[data_Bananas_Rwanda['mp_year'] == 2008]
# Out:
#         adm0_id adm0_name  adm1_id                     adm1_name  mkt_id  \
# 532934      205    Rwanda     2587  Kigali City/Umujyi wa Kigali    1091
#
#          mkt_name  cm_id  cm_name  cur_id cur_name  pt_id pt_name  um_id  \
# 532934  Nyabugogo    254  Bananas      77      RWF     15  Retail      5
#
#        um_name  mp_month  mp_year  mp_price mp_commoditysource
# 532934      KG        11     2008     533.0            MINAGRI

# %% [markdown]
# Only 1 row about 2008. So the price analysis of 2008 is not inconclusive.
# From 2009 to 2011, the bananas' unit-price rised. But when time came to 2012, the average price decreased more than 200. After 2012, the price kept on increasing in 3 years, modestly.
#
# And we can also tell that after 2012, the price is more steady.

# %% [markdown]
# # Are any of the columns correlated?

# %%
data_M_MF_Rwanda = data_Rwanda.loc[(data_Rwanda['cm_name'] == 'Maize')| (data_Rwanda['cm_name'] == 'Maize flour')]
data_M_MF_Rwanda
# Out:
#         adm0_id adm0_name  adm1_id             adm1_name  mkt_id mkt_name  \
# 466046      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466047      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466048      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466049      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466050      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466051      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466052      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466053      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466054      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466055      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466056      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466057      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466058      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466059      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466060      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466061      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466062      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466063      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466064      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466065      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466066      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466067      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466068      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466069      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466070      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466071      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466072      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466073      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466074      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# 466075      205    Rwanda    21973  $West/Iburengerazuba    1045  Birambo
# ...         ...       ...      ...                   ...     ...      ...
# 580221      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580222      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580223      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580224      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580225      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580226      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580227      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580228      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580229      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580230      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580231      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580232      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580233      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580234      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580235      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580236      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580237      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580238      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580239      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580240      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580241      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580242      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580243      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580244      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580245      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580246      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580247      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580248      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580249      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
# 580250      205    Rwanda    21971   $North/Amajyaruguru    1562   Rusine
#
#         cm_id      cm_name  cur_id cur_name  pt_id pt_name  um_id um_name  \
# 466046     51        Maize      77      RWF     15  Retail      5      KG
# 466047     51        Maize      77      RWF     15  Retail      5      KG
# 466048     51        Maize      77      RWF     15  Retail      5      KG
# 466049     51        Maize      77      RWF     15  Retail      5      KG
# 466050     51        Maize      77      RWF     15  Retail      5      KG
# 466051     51        Maize      77      RWF     15  Retail      5      KG
# 466052     51        Maize      77      RWF     15  Retail      5      KG
# 466053     51        Maize      77      RWF     15  Retail      5      KG
# 466054     51        Maize      77      RWF     15  Retail      5      KG
# 466055     51        Maize      77      RWF     15  Retail      5      KG
# 466056     51        Maize      77      RWF     15  Retail      5      KG
# 466057     51        Maize      77      RWF     15  Retail      5      KG
# 466058     51        Maize      77      RWF     15  Retail      5      KG
# 466059     51        Maize      77      RWF     15  Retail      5      KG
# 466060     51        Maize      77      RWF     15  Retail      5      KG
# 466061     51        Maize      77      RWF     15  Retail      5      KG
# 466062     51        Maize      77      RWF     15  Retail      5      KG
# 466063     51        Maize      77      RWF     15  Retail      5      KG
# 466064     51        Maize      77      RWF     15  Retail      5      KG
# 466065     51        Maize      77      RWF     15  Retail      5      KG
# 466066     51        Maize      77      RWF     15  Retail      5      KG
# 466067     51        Maize      77      RWF     15  Retail      5      KG
# 466068     51        Maize      77      RWF     15  Retail      5      KG
# 466069     51        Maize      77      RWF     15  Retail      5      KG
# 466070     51        Maize      77      RWF     15  Retail      5      KG
# 466071     51        Maize      77      RWF     15  Retail      5      KG
# 466072     51        Maize      77      RWF     15  Retail      5      KG
# 466073     51        Maize      77      RWF     15  Retail      5      KG
# 466074     51        Maize      77      RWF     15  Retail      5      KG
# 466075     51        Maize      77      RWF     15  Retail      5      KG
# ...       ...          ...     ...      ...    ...     ...    ...     ...
# 580221     76  Maize flour      77      RWF     15  Retail      5      KG
# 580222     76  Maize flour      77      RWF     15  Retail      5      KG
# 580223     76  Maize flour      77      RWF     15  Retail      5      KG
# 580224     76  Maize flour      77      RWF     15  Retail      5      KG
# 580225     76  Maize flour      77      RWF     15  Retail      5      KG
# 580226     76  Maize flour      77      RWF     15  Retail      5      KG
# 580227     76  Maize flour      77      RWF     15  Retail      5      KG
# 580228     76  Maize flour      77      RWF     15  Retail      5      KG
# 580229     76  Maize flour      77      RWF     15  Retail      5      KG
# 580230     76  Maize flour      77      RWF     15  Retail      5      KG
# 580231     76  Maize flour      77      RWF     15  Retail      5      KG
# 580232     76  Maize flour      77      RWF     15  Retail      5      KG
# 580233     76  Maize flour      77      RWF     15  Retail      5      KG
# 580234     76  Maize flour      77      RWF     15  Retail      5      KG
# 580235     76  Maize flour      77      RWF     15  Retail      5      KG
# 580236     76  Maize flour      77      RWF     15  Retail      5      KG
# 580237     76  Maize flour      77      RWF     15  Retail      5      KG
# 580238     76  Maize flour      77      RWF     15  Retail      5      KG
# 580239     76  Maize flour      77      RWF     15  Retail      5      KG
# 580240     76  Maize flour      77      RWF     15  Retail      5      KG
# 580241     76  Maize flour      77      RWF     15  Retail      5      KG
# 580242     76  Maize flour      77      RWF     15  Retail      5      KG
# 580243     76  Maize flour      77      RWF     15  Retail      5      KG
# 580244     76  Maize flour      77      RWF     15  Retail      5      KG
# 580245     76  Maize flour      77      RWF     15  Retail      5      KG
# 580246     76  Maize flour      77      RWF     15  Retail      5      KG
# 580247     76  Maize flour      77      RWF     15  Retail      5      KG
# 580248     76  Maize flour      77      RWF     15  Retail      5      KG
# 580249     76  Maize flour      77      RWF     15  Retail      5      KG
# 580250     76  Maize flour      77      RWF     15  Retail      5      KG
#
#         mp_month  mp_year  mp_price mp_commoditysource
# 466046        11     2010  179.0000            MINAGRI
# 466047        12     2010  189.6667            MINAGRI
# 466048         1     2011  185.2500            MINAGRI
# 466049         2     2011  187.0000            MINAGRI
# 466050         3     2011  186.2000            MINAGRI
# 466051         4     2011  183.0000            MINAGRI
# 466052         5     2011  204.0000            MINAGRI
# 466053         6     2011  209.2500            MINAGRI
# 466054         7     2011  226.5000            MINAGRI
# 466055         8     2011  213.2000            MINAGRI
# 466056         9     2011  219.2500            MINAGRI
# 466057        10     2011  227.5000            MINAGRI
# 466058        11     2011  229.4000            MINAGRI
# 466059        12     2011  241.0000            MINAGRI
# 466060         1     2012  242.5000            MINAGRI
# 466061         2     2012  247.5000            MINAGRI
# 466062         3     2012  232.5000            MINAGRI
# 466063         4     2012  209.0000            MINAGRI
# 466064         5     2012  230.4000            MINAGRI
# 466065         6     2012  242.5000            MINAGRI
# 466066         7     2012  240.0000            MINAGRI
# 466067         8     2012  260.0000            MINAGRI
# 466068         9     2012  265.0000            MINAGRI
# 466069        10     2012  263.0000            MINAGRI
# 466070        11     2012  249.5000            MINAGRI
# 466071        12     2012  262.6667            MINAGRI
# 466072         1     2013  269.0000            MINAGRI
# 466073         2     2013  243.0000            MINAGRI
# 466074         3     2013  208.0000            MINAGRI
# 466075         4     2013  208.2500            MINAGRI
# ...          ...      ...       ...                ...
# 580221         7     2013  416.0000            MINAGRI
# 580222         8     2013  416.0000            MINAGRI
# 580223         9     2013  408.2500            MINAGRI
# 580224        10     2013  416.0000            MINAGRI
# 580225        11     2013  433.0000            MINAGRI
# 580226        12     2013  416.0000            MINAGRI
# 580227         1     2014  416.0000            MINAGRI
# 580228         2     2014  416.0000            MINAGRI
# 580229         3     2014  383.0000            MINAGRI
# 580230         4     2014  375.0000            MINAGRI
# 580231         5     2014  383.0000            MINAGRI
# 580232         6     2014  362.2500            MINAGRI
# 580233         7     2014  383.0000            MINAGRI
# 580234         8     2014  383.0000            MINAGRI
# 580235         9     2014  383.0000            MINAGRI
# 580236        10     2014  383.0000            MINAGRI
# 580237        11     2014  383.0000            MINAGRI
# 580238        12     2014  383.0000            MINAGRI
# 580239         1     2015  391.2500            MINAGRI
# 580240         2     2015  383.0000            MINAGRI
# 580241         3     2015  366.0000            MINAGRI
# 580242         4     2015  366.0000            MINAGRI
# 580243         5     2015  368.2500            MINAGRI
# 580244         6     2015  350.0000            MINAGRI
# 580245         7     2015  350.0000            MINAGRI
# 580246         8     2015  350.0000            MINAGRI
# 580247         9     2015  353.2000            MINAGRI
# 580248        10     2015  374.5000            MINAGRI
# 580249        11     2015  366.0000            MINAGRI
# 580250        12     2015  366.0000            MINAGRI
#
# [8354 rows x 18 columns]

# %%
sns.stripplot(x = "mp_year", y = "mp_price", hue="cm_name", data = data_M_MF_Rwanda,size=10, jitter=True)

# %%
sns.lmplot(x = "mp_year", y = "mp_price", hue="cm_name",x_jitter=.35, data = data_M_MF_Rwanda,size=10)

# %%
sns.pointplot(x = "mp_year", y = "mp_price", hue = "cm_name",data = data_M_MF_Rwanda)

# %% [markdown]
# As expected, the price of maize and maize flour are correlated, and the plot says these two kinds of food have a similar tendancy of unit-price.

# %% [markdown]
# - ----------------------------------
# -- --
# # Part B

# %%
from __future__ import print_function
import urllib3 #  pip install -i https://pypi.anaconda.org/pypi/simple urllib3
import unicodedata
from bs4 import BeautifulSoup, SoupStrainer, Comment
import warnings
warnings.filterwarnings('ignore')

# %%
url='http://searchstorage.techtarget.com/tip/How-to-use-REST-APIs-in-Python'

# %%
http = urllib3.PoolManager()
response = http.request('GET',url)
response.status
# Out:
# 200

# %%
soup=BeautifulSoup(response.data, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if gt IE 8]><!-->
# <html class="no-js gt-ie8" dir="ltr" itemscope="" itemtype="http://schema.org/Article" lang="en" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    How to use REST APIs in Python
#   </title>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="It's important for storage administrators who are after open management to know a little bit about using REST APIs in Python." name="description"/>
#   <meta content="noodp" name="robots"/>
#   <link href="http://searchstorage.techtarget.com/tip/How-to-use-REST-APIs-in-Python" rel="canonical"/>
#   <meta content="How to use REST APIs in Python" property="og:title"/>
#   <meta content="SearchStorage" property="og:site_name"/>
#   <meta content="http://searchstorage.techtarget.com/tip/How-to-use-REST-APIs-in-Python" property="og:url"/>
#   <meta content="It's important for storage administrators who are after open management to know a little bit about using REST APIs in Python." property="og:description"/>
#   <meta content="870327132989388" property="fb:app_id"/>
#   <meta content="article" property="og:type"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="https://www.facebook.com/Search-Storage/10150115721885374" property="article:publisher"/>
#   <meta content="How to use REST APIs in Python" itemprop="name"/>
#   <meta content="It's important for storage administrators who are after open management to know a little bit about using REST APIs in Python." itemprop="description"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@searchstoragett" name="twitter:site"/>
#   <meta content="How to use REST APIs in Python" name="twitter:title"/>
#   <meta content="It's important for storage administrators who are after open management to know a little bit about using REST APIs in Python." name="twitter:description"/>
#   <meta content="https://cdn.ttgtmedia.com/ITKE/images/logos/TTlogo-379x201.png" property="og:image"/>
#   <meta content="https://cdn.ttgtmedia.com/ITKE/images/logos/TTlogo-379x201.png" itemprop="image"/>
#   <meta content="https://cdn.ttgtmedia.com/visuals/searchSOA/web_services_development/soa_article_022.jpg" property="og:image"/>
#   <meta content="https://cdn.ttgtmedia.com/visuals/searchSOA/web_services_development/soa_article_022.jpg" itemprop="image"/>
#   <meta content="https://cdn.ttgtmedia.com/visuals/searchSOA/web_services_development/soa_article_022.jpg" name="twitter:image"/>
#   <link href="http://searchstorage.techtarget.com/rss/News-and-trends-in-the-storage-industry.xml" rel="alternate" title="SearchStorage: News and trends in the storage industry" type="application/rss+xml"/>
#   <link href="http://whatis.techtarget.com/rss/Enterprise-IT-tips-and-expert-advice.xml" rel="alternate" title="WhatIs.com: Enterprise IT tips and expert advice" type="application/rss+xml"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js">
#   </script>
#   <script src="https://fast.fonts.net/jsapi/124d48dd-e515-4302-8bfb-1d5c1e3da916.js">
#   </script>
#   <link href="https://cdn.ttgtmedia.com/rms/ux/responsive/css/main.css?v=7.1" rel="stylesheet"/>
#   <script src="https://cdn.ttgtmedia.com/rms/ux/responsive/js/responsive.min.js?v=7.1">
#   </script>
#   <script type="text/javascript">
#    var _vwo_code=(function(){var account_id=329923,settings_tolerance=2000,library_tolerance=2500,use_existing_jquery=false,f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());return settings_timer;}};}());_vwo_settings_timer=_vwo_code.init();
#   </script>
#   <script>
#    TT("page", {"topical":true,"parentTopicName":"Cloud storage","siteName":"searchStorage","appCode":"55","uaid":"UA-19046353-19","adAbbr":"sstr","parentTopicId":"316063","zone":"TIPS","ga":true,"lang":"en","regTopicName":"Cloud computing storage environments","timestamp":"2018-02-02 14:19:19","siteType":"editorial","gaPageTrackUrl":"/page/etpk_Cloud storage-316063/ptpk_Cloud storage management and standards-450423933/true/TIPS/content/cid_450433401/date_20180117/mem_55/rtpk_Cloud computing storage environments-1330961/idx_0","homeAdId":"2240013174","regTopicId":"1330961","pubDate":"20180117","membersOnly":true,"adScheme":"1","ttgtRegHost":"https://users.techtarget.com","atHost":"https://go.techtarget.com","regHost":"https://users.techtarget.com","topicId":"450423933","adId":"450433401","pageIndex":0,"siteId":5,"topicName":"Cloud storage management and standards","topicIds":["450423933","450423940"],"gaSiteAcct":"UA-19046353-19"});
#   </script>
#   <!-- Begin Chartbeat -->
#   <script>
#    var _sf_startpt=(new Date()).getTime();
#   </script>
#   <!-- End Chartbeat -->
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={xpid:"VwcDVVZACwIDU1lS"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r) ...
#   </script>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144×144"/>
#   <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114×114"/>
#   <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72×72"/>
#   <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/>
#   <link href="/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144×144"/>
#   <link href="/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114×114"/>
#   <link href="/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72×72"/>
#   <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
#  </head>
#  <body class="reg-login" id="tips">
#   <!-- Begin Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PWWZSH" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-PWWZSH');
#   </script>
#   <!-- End Google Tag Manager -->
#   <div class="site-container" id="site-container">
#    <!-- PinnedNavBarController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#    <!-- AdsController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#    <div class="ad ad-ist" id="interstitial">
#     <script>
#      GPT.display('interstitial')
#     </script>
#    </div>
#    <div class="ad-wrapper header-leaderboard ad-mobile">
#     <!-- AdsController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#     <div class="ad ad-mb" id="mobile-lb">
#      <script>
#       GPT.display('mobile-lb')
#      </script>
#     </div>
#    </div>
#    <header class="header header_v2 en" id="page-header">
#     <button class="nav-toggle">
#      <i class="icon" data-icon="9">
#      </i>
#     </button>
#     <a class="header-logo mobile-link" href="http://www.techtarget.com/network">
#      <span class="header-logo-mobile">
#       SearchStorage
#      </span>
#     </a>
#     <a class="header-logo desktop-link" href="http://searchstorage.techtarget.com">
#      <img alt="TechTarget" class="header-logo-desktop replace_2x" src="https://cdn.ttgtmedia.com/rms/ux/responsive/img/nav_logo.png"/>
#      <img alt="TechTarget" class="header-logo-small replace_2x" src="https://cdn.ttgtmedia.com/rms/ux/responsive/img/nav_logo.png"/>
#     </a>
#     <button class="header-search-toggle">
#      <i class="icon" data-icon="g">
#      </i>
#     </button>
#     <form action="https://www.techtarget.com/search/query" class="header-search" method="get">
#      <label class="visuallyhidden" for="header-search-input">
#       Search the TechTarget Network
#      </label>
#      <input autocomplete="off" class="header-search-input ui-autocomplete-input" id="header-search-input" name="q" placeholder="Search the TechTarget Network" type="text"/>
#      <button class="header-search-submit">
#       <i class="icon" data-icon="g">
#       </i>
#      </button>
#     </form>
#     <nav class="nav">
#      <a class="nav-join-pro" href="https://users.techtarget.com/registration/searchStorage/LoginRegister.page">
#       <span>
#        Sign-up now. Start my free, unlimited access.
#       </span>
#      </a>
#      <div class="nav-user">
#       <a href="https://users.techtarget.com/registration/searchStorage/LoginRegister.page">
#        <span class="nav-user-action">
#         Login
#        </span>
#       </a>
#       <a class="register" href="https://users.techtarget.com/registration/searchStorage/Register.page">
#        <span class="nav-user-action">
#         Register
#        </span>
#       </a>
#      </div>
#      <script>
#       TT(["context","lib/jquery"],function(c,$){var u=c.getUser();if(u.loggedIn){$('div.nav-user').children("a:first")
# 			.before('<i class="icon header_logged_in_icon" title="'+u.displayName+'"></i>')
# 			.attr("href", "https://users.techtarget.com/registration/searchStorage/Logout.page?fromURL=" + window.location.href).children("span.nav-user-action:first").text('Logout');
# 			$('.register').removeAttr('href');$('a.register').hide();}else{$('div.nav-user').children("a:first").attr("href", "https://users.techtarget.com/registration/searchStorage/LoginRegister.page?fromURL="+window.location.href);
# 			$('a.nav-join-pro').attr("href", "https://users.techtarget.com/registration/searchStorage/LoginRegister.page?fromURL="+window.location.href);}});
#      </script>
#      <div class="nav-links">
#       <ul>
#        <li id="nav-links-TechtargetNetwork">
#         <a href="http://www.techtarget.com/network">
#          Techtarget Network
#         </a>
#        </li>
#        <li id="nav-links-News">
#         <a href="http://searchstorage.techtarget.com/info/news">
#          News
#         </a>
#        </li>
#        <li id="nav-links-Features">
#         <a href="http://searchstorage.techtarget.com/features">
#          Features
#         </a>
#        </li>
#        <li id="nav-links-Tips">
#         <a href="http://searchstorage.techtarget.com/tips">
#          Tips
#         </a>
#        </li>
#        <li class="more-content">
#         <a href="#">
#          More Content
#          <i class="icon icon-arrow-down" data-icon="5">
#          </i>
#         </a>
#         <div class="more-content-dropdown">
#          <ul class="nav-list-sublist">
#           <li id="nav-links-Answers">
#            <a href="http://searchstorage.techtarget.com/answers">
#             Answers
#            </a>
#           </li>
#           <li id="nav-links-Buyer'sGuides">
#            <a href="http://whatis.techtarget.com/resources/Buyers-Guides">
#             Buyer's Guides
#            </a>
#           </li>
#           <li id="nav-links-Definitions">
#            <a href="http://searchstorage.techtarget.com/definitions">
#             Definitions
#            </a>
#           </li>
#           <li id="nav-links-EssentialGuides">
#            <a href="http://searchstorage.techtarget.com/guides">
#             Essential Guides
#            </a>
#           </li>
#           <li id="nav-links-Opinions">
#            <a href="http://searchstorage.techtarget.com/opinions">
#             Opinions
#            </a>
#           </li>
#           <li id="nav-links-PhotoStories">
#            <a href="http://searchstorage.techtarget.com/photostories">
#             Photo Stories
#            </a>
#           </li>
#           <li id="nav-links-Podcasts">
#            <a href="http://searchstorage.techtarget.com/podcasts">
#             Podcasts
#            </a>
#           </li>
#           <li id="nav-links-Quizzes">
#            <a href="http://searchstorage.techtarget.com/quizzes">
#             Quizzes
#            </a>
#           </li>
#           <li id="nav-links-Tutorials">
#            <a href="http://searchstorage.techtarget.com/tutorials">
#             Tutorials
#            </a>
#           </li>
#           <li class="nav-links-sponsoredcommunities">
#            <a href="http://searchstorage.techtarget.com/sponsored_communities">
#             Sponsored Communities
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li>
#         <a href="http://searchstorage.techtarget.com/blog/Storage-Soup">
#          Storage Soup Blog
#         </a>
#        </li>
#       </ul>
#      </div>
#      <ul class="nav-list">
#       <li class="nav-list-item nav-list-item-searchsites">
#        <div class="nav-list-item-header searchstorage">
#         <a href="http://searchstorage.techtarget.com">
#          <span class="nav-list-item-header-title">
#           <span class="logo-search">
#            Search
#           </span>
#           <span class="logo-1">
#            Storage
#           </span>
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="nav-list-item nav-list-item-topics">
#        <div class="nav-list-item-header">
#         <span class="nav-list-item-header-type">
#          Topic
#         </span>
#         <span class="nav-list-item-header-title">
#          <a href="http://searchstorage.techtarget.com/resources/Cloud-Storage">
#           Cloud storage
#          </a>
#         </span>
#         <i class="icon icon-arrow-down" data-icon="5">
#         </i>
#         <i class="icon icon-navigation-detail" data-icon="A">
#         </i>
#        </div>
#        <div class="nav-list-item-dropdown">
#         <div class="nav-list-item-jscroll">
#          <ul class="nav-list-sublist">
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Application-storage">
#             Application storage
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Flash-memory">
#             Flash memory
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Object-storage">
#             Object storage
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Primary-storage-devices">
#             Primary storage  devices
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Software-defined-storage">
#             Software-defined storage
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Solid-State-Storage">
#             Solid-state storage
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Storage-management-and-analytics">
#             Storage management and analytics
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Storage-market-research-reports">
#             Storage market research reports
#            </a>
#           </li>
#           <li class="nav-list-sublist-item">
#            <a href="http://searchstorage.techtarget.com/resources/Storage-vendors">
#             Storage vendors
#            </a>
#           </li>
#           <li class="nav-list-sublist-item view-all">
#            <a href="http://searchstorage.techtarget.com/resources">
#             All Topics
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="nav-list-item nav-list-item-sections">
#        <div class="nav-list-item-header">
#         <span class="nav-list-item-header-type">
#          SubTopic
#         </span>
#         <i class="icon icon-arrow-down" data-icon="5">
#         </i>
#         <i class="icon icon-navigation-arrow" data-icon="B">
#         </i>
#         <span class="nav-list-item-header-title">
#          <a href="http://searchstorage.techtarget.com/resources/Cloud-storage-management-and-standards">
#           Cloud storage management and standards
#          </a>
#         </span>
#        </div>
#        <div class="nav-list-sublist nav-list-item-dropdown">
#         <ul class="nav-list-item-jscroll">
#          <li class="nav-list-sublist-item">
#           <a href="http://searchstorage.techtarget.com/resources/Cloud-storage-gateways">
#            Cloud storage gateways
#           </a>
#          </li>
#          <li class="nav-list-sublist-item">
#           <a href="http://searchstorage.techtarget.com/resources/Cloud-storage-management-and-standards">
#            Cloud storage management and standards
#           </a>
#          </li>
#          <li class="nav-list-sublist-item">
#           <a href="http://searchstorage.techtarget.com/resources/Hybrid-cloud-storage">
#            Hybrid cloud storage
#           </a>
#          </li>
#          <li class="nav-list-sublist-item">
#           <a href="http://searchstorage.techtarget.com/resources/Private-Cloud-Storage">
#            Private cloud
#           </a>
#          </li>
#          <li class="nav-list-sublist-item">
#           <a href="http://searchstorage.techtarget.com/resources/Public-Cloud-Storage">
#            Public cloud
#           </a>
#          </li>
#          <li class="nav-list-sublist-item view-all">
#           <a href="http://searchstorage.techtarget.com/resources/Cloud-Storage">
#            All Subtopics
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#      </ul>
#      <ul class="nav-social">
#       <li class="nav-social-item title">
#        Follow:
#       </li>
#       <li class="nav-social-item" id="navBarGooglePlus" title="Follow searchStorage on Google+">
#        <a href="https://plus.google.com/u/0/106000202575757202315" target="_blank">
#         <i class="icon" data-icon="s">
#         </i>
#        </a>
#       </li>
#       <li class="nav-social-item" id="navBarFacebook" title="Like searchStorage on Facebook">
#        <a href="https://www.facebook.com/Search-Storage/10150115721885374" target="_blank">
#         <i class="icon" data-icon="u">
#         </i>
#        </a>
#       </li>
#       <li class="nav-social-item" id="navBarTwitter" title="Follow @searchstoragett on Twitter">
#        <a href="https://twitter.com/searchstoragett" target="_blank">
#         <i class="icon" data-icon="c">
#         </i>
#        </a>
#       </li>
#       <li class="nav-social-item" id="navBarLinkedIn" title="Follow searchStorage on LinkedIn">
#        <a href="http://www.linkedin.com/company/3007485?trk=tyah" target="_blank">
#         <i class="icon" data-icon="o">
#         </i>
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </header>
#    <div class="ad-wrapper header-leaderboard ad-desktop">
#     <!-- AdsController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#     <div class="ad ad-lb" id="leaderboard">
#      <script>
#       GPT.display('leaderboard')
#      </script>
#     </div>
#    </div>
#    <div class="main-content" id="main-content">
#     <article class="content-columns" id="content-columns">
#      <!-- ContentItemController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#      <header class="main-article-header" id="content-header">
#       <div class="infotype-eyebrow">
#        <a class="infotype-eyebrow-link" href="http://searchstorage.techtarget.com/info/getstarted">
#         Get started
#        </a>
#        <span class="infotype-eyebrow-tooltip">
#         <i class="icon" data-icon="5">
#         </i>
#         Bring yourself up to speed with our introductory content.
#        </span>
#       </div>
#       <h1 class="main-article-title">
#        How to use REST APIs in Python
#       </h1>
#       <ul class="main-article-share-counts">
#        <li class="main-article-share-count main-article-comment-count" title="Add/view comments">
#         <i class="icon" data-icon="z">
#         </i>
#         <span>
#         </span>
#        </li>
#        <li class="main-article-share-count inline-social-icons inline cboxElement" href="#social-icons-desktop" title="Share this">
#         <i class="icon" data-icon="f">
#         </i>
#         <span>
#         </span>
#        </li>
#       </ul>
#       <div class="ad-wrapper page-header-ad ad-desktop">
#        <!-- AdsController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#        <div class="ad ad-mu" id="mu-top">
#         <script>
#          GPT.display('mu-top')
#         </script>
#        </div>
#       </div>
#       <div class="main-article-author">
#        <div class="main-article-author-info">
#         <div class="main-article-author-byline">
#          by Gábor Nyers
#         </div>
#        </div>
#       </div>
#       <h2 class="main-article-subtitle">
#        Using REST APIs with Python can offer storage administrators increased flexibility in their management tasks, but they need some knowledge of how to code.
#       </h2>
#      </header>
#      <!-- RefineryController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#      <!-- GuideController, generated at 14:17:45 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#      <div class="content-left" id="content-left">
#       <div class="locking-full-bar">
#        <div class="locking-left-bar">
#         <!-- ChaptersBarController, generated at 14:17:44 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#         <nav class="chapters-bar desktop-chapters-bar" data-required-item="section.main-article-chapter" id="chapters-bar-menu">
#          <div class="chapters-bar-header">
#           <i class="icon" data-icon="1">
#           </i>
#           Sections
#          </div>
#          <ul class="chapters-bar-list">
#          </ul>
#         </nav>
#         <!-- GuideController, generated at 14:17:41 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#         <!-- SocialMediaShareBarController, generated at 14:17:55 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#         <div id="rail-share-bar">
#          <ul class="share-bar-desktop" id="social-icons-desktop">
#           <aside id="social-icons-desktop">
#            <li class="share-bar-item-desktop share-bar-title">
#             Share this item with your network:
#            </li>
#            <li class="share-bar-item-desktop socialMedia-facebook" data-socialsite="facebook" title="Share on Facebook">
#             <a href="#" target="_blank">
#              <i class="icon" data-icon="u">
#              </i>
#             </a>
#             <span class="count">
#             </span>
#            </li>
#            <li class="share-bar-item-desktop socialMedia-twitter" data-account="searchstoragett" data-related="" data-socialsite="twitter" title="Share on Twitter">
#             <a href="#" target="_blank">
#              <i class="icon" data-icon="c">
#              </i>
#             </a>
#             <span class="count">
#             </span>
#            </li>
#            <li class="share-bar-item-desktop socialMedia-google" data-socialsite="google" title="Share on Google+">
#             <a href="#" target="_blank">
#              <i class="icon" data-icon="s">
#              </i>
#             </a>
#             <span class="count">
#             </span>
#            </li>
#            <li class="share-bar-item-desktop socialMedia-linkedin" data-socialsite="linkedin" title="Share on LinkedIn">
#             <a href="#" target="_blank">
#              <i class="icon" data-icon="o">
#              </i>
#             </a>
#             <span class="count">
#             </span>
#            </li>
#            <li class="share-bar-item-desktop contentTools-print" title="Print This Page">
#             <a href="#" target="_blank">
#              <i class="icon" data-icon="i">
#              </i>
#             </a>
#            </li>
#            <li class="share-bar-item-desktop contentTools-email" title="Email a Friend">
#             <a href="#" target="_blank">
#              <i class="icon" data-icon="n">
#              </i>
#             </a>
#            </li>
#           </aside>
#          </ul>
#         </div>
#         <!-- RelatedContentController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#         <aside class="related-bar desktop-related-bar" id="related-content-bar">
#          <div class="related-bar-header">
#           <i class="icon" data-icon="l">
#           </i>
#           Related Content
#          </div>
#          <ul class="related-bar-list">
#           <li class="related-bar-item">
#            <a href="http://searchaws.techtarget.com/tip/Boto-gains-foothold-as-AWS-SDK-for-Python-standard">
#             Boto gains foothold as AWS SDK for Python standard
#            </a>
#            <span>
#             – SearchAWS
#            </span>
#           </li>
#           <li class="related-bar-item">
#            <a href="http://searchaws.techtarget.com/definition/Boto">
#             Boto
#            </a>
#            <span>
#             – SearchAWS
#            </span>
#           </li>
#           <li class="related-bar-item">
#            <a href="http://searchaws.techtarget.com/tip/AWS-SDKs-match-services-to-language-platform">
#             AWS SDKs match services to language, platform
#            </a>
#            <span>
#             – SearchAWS
#            </span>
#           </li>
#          </ul>
#         </aside>
#        </div>
#        <aside class="resources-bar desktop-resources-bar" id="resources-bar">
#         <!-- VendorResourcesController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#         <div class="resources-bar-header">
#          <i class="icon" data-icon="l">
#          </i>
#          Sponsored News
#         </div>
#         <ul class="resources-bar-list sponsored-news">
#          <li class="resources-bar-item">
#           <a href="http://www.convergedinfrastructure.com/The-Lowdown-on-Software-Defined-Storage-in-the-Data-Center?asrc=SS_sstr_SN-450433401">
#            The Lowdown on Software-Defined Storage in the Data Center
#           </a>
#           <span>
#            –Dell EMC
#           </span>
#          </li>
#          <li class="resources-bar-item">
#           <a href="http://searchstorage.techtarget.com/hyperconvergedspotlight/One-More-Reason-to-Use-HCI-Bolstering-Security?asrc=SS_sstr_SN-450433401">
#            One More Reason to Use HCI: Bolstering Security
#           </a>
#           <span>
#            –VMware
#           </span>
#          </li>
#          <li class="resources-bar-item see-more">
#           <a href="http://searchstorage.techtarget.com/sponsored_communities">
#            See More
#           </a>
#          </li>
#         </ul>
#         <div class="resources-bar-header">
#          <i class="icon" data-icon="l">
#          </i>
#          Vendor Resources
#         </div>
#         <ul class="resources-bar-list" id="vendorResourcesSplash">
#          <li class="resources-bar-item">
#           <a href="https://www.bitpipe.com/detail/RES/1515782281_21.html">
#            A Hybrid Cloud Approach To Big Data In The Enterprise
#           </a>
#           <span>
#            –Stratoscale
#           </span>
#           <i class="icon" data-icon="8">
#           </i>
#          </li>
#         </ul>
#        </aside>
#       </div>
#      </div>
#      <div class="content-center" id="content-center">
#       <!-- EzinePromoController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#       <!-- ContentItemController, generated at 14:19:19 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#       <div class="float-mask">
#       </div>
#       <ul class="actions-bar">
#        <li class="actions-bar-item actions-bar-chapters">
#         <i class="icon" data-icon="1">
#         </i>
#        </li>
#        <li class="actions-bar-item actions-bar-resources">
#         <i class="icon" data-icon="2">
#         </i>
#        </li>
#        <li class="actions-bar-item actions-bar-share">
#         <i class="icon" data-icon="f">
#         </i>
#         <ul class="share-bar-mobile">
#          <aside id="social-icons-desktop">
#           <li class="share-bar-item-mobile socialMedia-facebook" data-socialsite="facebook" title="Share on Facebook">
#            <a href="#">
#             <i class="icon" data-icon="u">
#             </i>
#            </a>
#            <span class="count">
#            </span>
#           </li>
#           <li class="share-bar-item-mobile socialMedia-twitter" data-account="searchstoragett" data-related="cloudstoragett" data-socialsite="twitter" title="Share on Twitter">
#            <a href="#">
#             <i class="icon" data-icon="c">
#             </i>
#            </a>
#            <span class="count">
#            </span>
#           </li>
#           <li class="share-bar-item-mobile socialMedia-google" data-socialsite="google" title="Share on Google+">
#            <a href="#">
#             <i class="icon" data-icon="s">
#             </i>
#            </a>
#            <span class="count">
#            </span>
#           </li>
#           <li class="share-bar-item-mobile socialMedia-linkedin" data-socialsite="linkedin" title="Share on LinkedIn">
#            <a href="#">
#             <i class="icon" data-icon="o">
#             </i>
#            </a>
#            <span class="count">
#            </span>
#           </li>
#           <li class="share-bar-item-mobile contentTools-email" title="Email a Friend">
#            <a href="#">
#             <i class="icon" data-icon="n">
#             </i>
#            </a>
#           </li>
#          </aside>
#         </ul>
#        </li>
#       </ul>
#       <section id="content-body">
#        <p>
#         Openness is increasing, thanks to the likes of Linux, OpenStack and Ceph. This trend has given rise to open APIs,...
#        </p>
#        <div id="inlineRegistrationWrapper">
#         <div id="inlineRegistration">
#          <div class="login-register inline-reg page1">
#           <a href="https://users.techtarget.com/registration/searchstorage/LoginRegister">
#            Sign in for existing members
#           </a>
#          </div>
#          <section class="sign-up-wrapper inline-reg page1">
#           <div class="sign-up-content">
#            <header class="sign-up-header">
#             <h2>
#              Continue Reading This Article
#             </h2>
#             <p>
#              Enjoy this article as well as all of our content, including E-Guides, news, tips and more.
#             </p>
#            </header>
#            <div class="meterContainer">
#             <div class="meterDescription">
#              Step 2 of 2:
#             </div>
#             <div class="meter">
#              <div class="green" id="percentage">
#              </div>
#             </div>
#            </div>
#            <form action="https://users.techtarget.com/registration/searchStorage/InlineRegisterActivate.page" class="sign-up-form" id="inlineregform" method="post" name="inlineregform">
#             <fieldset>
#              <ul class=" default-list">
#               <script>
#                window["inlineRegistration_VALIDATION_MAXLENGTH"] = "You have exceeded the maximum character limit.";
#               </script>
#               <li>
#                <input class="sign-up-textfield progressBarItem" data-required="true" id="inlineRegistration_Email" maxlength="100" name="dgUser#email" placeholder="corporate email address" size="25" type="text" value=""/>
#                <div class="signupErrors">
#                 <p class="sign-up-error-msg hidden" id="inlineRegistration_Email.blank">
#                  You forgot to provide an Email Address.
#                 </p>
#                 <p class="sign-up-error-msg hidden" id="inlineRegistration_Email.invalid">
#                  This email address doesn’t appear to be valid.
#                 </p>
#                 <p class="sign-up-error-msg hidden" id="inlineRegistration_Email.exists">
#                  This email address is already registered. Please
#                  <a class="inlineRegLoginErrMsg" href="https://users.techtarget.com/registration/searchstorage/LoginRegister">
#                   login
#                  </a>
#                  .
#                 </p>
#                 <p class="sign-up-error-msg hidden" id="inlineRegistration_Email.maxlength">
#                  You have exceeded the maximum character limit.
#                 </p>
#                 <p class="sign-up-error-msg hidden" id="inlineRegistration_Email.invalid.domain">
#                  Please provide a Corporate E-mail Address.
#                 </p>
#                </div>
#                <input id="inlineRegistration_AppCode" name="appCD" type="hidden" value="55"/>
#                <input id="inlineRegistration_ContentId" name="guideContentId" type="hidden" value=""/>
#                <input id="inlineRegistration_AdId" name="ad_id" type="hidden" value="450433401"/>
#                <input id="inlineRegistration_TEST---AB-Tracking1" name="dgUser#abTracking1" type="hidden" value=""/>
#               </li>
#               <li class="">
#                <input class="sign-up-btn" id="inlineRegSubmit" type="submit" value="Continue Reading"/>
#               </li>
#               <div id="inlineRegProcessing" style="margin:30px 0px 15px 140px; display:none">
#                <span class="processing" style="display:inline">
#                 <span class="animatedIcon">
#                 </span>
#                 <span id="inlineRegProcessingText">
#                 </span>
#                </span>
#               </div>
#               <p class="declarationOfConsent" id="inlineRegistration_declarationOfConsent" style="display:none">
#                By submitting my Email address I confirm that I have read and accepted the Terms of Use and
#                <a class="consentWindow" href="https://users.techtarget.com/registration/searchStorage/DisplayConsentText.page?languageCd=en&amp;enText=true">
#                 Declaration of Consent.
#                </a>
#               </p>
#               <input id="inlineRegistration_Consent-Popup" name="user_consent#link" type="hidden" value="en"/>
#              </ul>
#             </fieldset>
#            </form>
#            <div>
#             <p class="sign-up-fine-print" style="font-size:12px">
#              By submitting your personal information, you agree that TechTarget and its
#              <a href="http://www.techtarget.com/html/privacy_partners_0-c.html" target="_blank">
#               partners
#              </a>
#              may contact you regarding relevant content, products and special offers.
#             </p>
#            </div>
#            <div style="margin-top:10px">
#             <p class="sign-up-fine-print" style="font-size:12px">
#              You also agree that your personal information may be transferred and processed in the United States, and that you have read and agree to the
#              <a href="http://searchstorage.techtarget.com/about/copyright" target="_blank">
#               Terms of Use
#              </a>
#              and the
#              <a href="http://www.techtarget.com/html/privacy_policy.html" target="_blank">
#               Privacy Policy
#              </a>
#              .
#             </p>
#            </div>
#           </div>
#          </section>
#          <script>
#           /**
#   * rename inlinereg div id specifid responsive v7 code.
#   */
# $("#inlineRegistrationContainer").attr("id", "inlineRegistration");
#
# /**
#   * rename "inlineRegistrationContainer_" ids with "inlineRegistration_" ids
#   */
# $.each($("[id^='inlineRegistrationContainer_']"), function () {
#
#   // determin newId
#   var newId = this.id.replace("inlineRegistrationContainer_", "inlineRegistration_");
#
#   if ($("label[for='"+this.id+"']") != undefined) {
#     // update 'for' label attribute for newId
#     $("label[for='"+this.id+"']").attr('for', newId);
#   }
#
#   // update to newId
#   $(this).attr('id', newId);
# });
#
# /**
#   * Replace with responsive error msg class
#   */
# renameErrorMsgClass();
#
# $(".sign-up-error-msg").each(function() {
#   if (! $(this).parent().hasClass("signupErrors")) {
#       var elm = this.outerHTML;
#       this.outerHTML = "<div class='signupErrors'>"+elm+"</div>";
#   }
# });
#
# /**
#   * remove unnecessary class from ul
#   */
# $("#inlineregform").find( "ul" ).removeClass("default-list");
#
# /**
#   * Replace "errorMessageInput" class with "sign-up-error-msg" class
#   */
# function renameErrorMsgClass() {
#     $(".errorMessageInput").each(function() {
#         if ($(this).hasClass("hidden")) {
#              $(this).removeClass("errorMessageInput hidden").addClass("sign-up-error-msg hidden");
#         } else {
#              $(this).removeClass("errorMessageInput").addClass("sign-up-error-msg");
#         }
#     });
# }
#
# /**
#   * when validation function is called, replace "errorMessageInput" with "sign-up-error-msg"
#   * before return
#   */
# function validateThis(v, form) {
#     var validateReturn = urValidation.validate(v, form);
#     renameErrorMsgClass();
#     return validateReturn;
# }
#
#
# /**
#   * DoC pop-up window js - included in moScripts.js which is not included in responsive page
#   */
# $("#inlineRegistration").on("click","a.consentWindow", function(e) {
#         window.open(this.href, "Consent", "width=500,height=600,scrollbars=1");
#         e.preventDefault();
# });
#          </script>
#          <script>
#           $(".meterContainer" ).hide();
#
# window.placeHolderBlankOut = function (othis) {
#   $this=$(othis); if($this.val() == $this.attr("placeholder")) $this.val("");
# };
#
# window.placeHolderInit = function (othis) {
#   $this=$(othis); if($this.val() == "") $this.val($this.attr("placeholder"));
# };
#
# //Populate placeholder values for IE
# (function ($) {
#   $.support.placeholder = ('placeholder' in document.createElement('input'));
# })(jQuery);
#
# if (!$.support.placeholder) {
#   $("#inlineregform").find("[placeholder]")
#   .each( function() { placeHolderInit(this); } )
#   .focus( function () { placeHolderBlankOut(this); } )
#   .blur( function () { placeHolderInit(this); } );
# }
#
# $("#inlineregform").submit(function(e) {
#
#   if($(this).hasClass("submitInProgress")) {
#     e.preventDefault();
#     return false;
#   } else {
#     $(this).addClass("submitInProgress")
#   }
#
#   if (!$.support.placeholder) {
#     $(this).find('[placeholder]').each( function() { placeHolderBlankOut(this); } );
#   }
#
#   var validation = {
#       msgInline: true,
#       highlightClass: "error",
#       highlightNode: "self",
#       errorMsgClass: "sign-up-error-msg",
#       triggerJqueryEvent: {
#           error: "tt.inlinereg.emailOnly.error",
#           submit: "tt.inlinereg.emailOnly.submit"
#       },
#       required: { fields: ["dgUser#email"] },
#       emailDomain: { fields: ["dgUser#email"] },
#       emailFormat: { fields: ["dgUser#email"] },
#       emailExists: {
#           field: "dgUser#email",
#           onsuccess: "irr",
#           onfailure: "uidfwd",
#           noHL: true,
#           noErrMsg: true,
#           processingGif: {
#               id: "inlineRegProcessing",
#               hideSubmitId: "inlineRegSubmit",
#               displayStyle: "block"
#           }
#       }
#   };
#
#   var isUrValid = urValidation.validate(validation, this);
#
#   if (!$.support.placeholder && !isUrValid) {
#     $(this).find('[placeholder]').each( function() { placeHolderInit(this); } );
#   }
#
#   if(!isUrValid) {
#    $(this).removeClass("submitInProgress");
#   }
#
#   return isUrValid;
# });
#
# window.uidfwd = function() {
#   window.location.href="https://users.techtarget.com/registration/searchStorage/UID.page?email="+encodeURIComponent(document.getElementById("inlineregform").elements["dgUser#email"].value);
# }
#          </script>
#          <script>
#           window.irr = function() {
#
#         $("#inlineRegSubmit").hide();
#         // $("#inlineRegProcessingText").html("Beginning Registration...")
#         $("#inlineRegProcessing").show();
#
#         var err = function() {
#             $("#inlineRegProcessing .animatedIcon").hide();
#             $("#inlineRegProcessingText").attr("class","error");
#             $("#inlineRegProcessingText").html("There was an error processing your information. Please try again later.");
#             $("#inlineRegistration").trigger("tt.inlinereg.emailOnly.error");
#         };
#
# 	var self = this;
# 	self.crs;
# 	self.tt_ut;
#
# 	var userregUrl = "https://users.techtarget.com/registration/rest/RegistrationService/";
# 	var f = $("#inlineregform")[0].elements;
# 	var userParams = {
# 		email: encodeURIComponent($.trim(f["dgUser#email"].value)),
# 		siteName: "searchStorage",
# 		appCode: encodeURIComponent(f["appCD"].value),
# 		adId: encodeURIComponent(f["ad_id"].value),
# 		contentId: encodeURIComponent(f["guideContentId"].value),
# 		utmSource: encodeURIComponent(getUtmSrcForReg()),
#                 abTracking1: encodeURIComponent(f["dgUser#abTracking1"].value)
# 	};
#
#         var passThruVars = {
#             FromURL: window.location.href,
#             AppCode: f["appCD"].value,
#             AdId: f["ad_id"].value,
#             ContentId: f["guideContentId"].value
#         };
#         window.inlineRegistration_variables = passThruVars;
#
# 	$.getJSON(userregUrl + "RegisterEmail?callback=?", userParams, function(data) {
# 		if(data.RegTx[0].status == 'SUCCESS') {
# 			var d = new Date();
# 			d.setTime(d.getTime()+(5*365*24*60*60*1000)); // 5yrs
# 			var expireDate = d.toGMTString();
# 			for (var i = 0; i < data.RegTx[0].cookies.cookie.length; i++) {
# 				var c = data.RegTx[0].cookies.cookie[i];
# 				document.cookie = c.name+"="+c.value+"; expires="+expireDate+"; path=/; domain="+getTopLevelDomainEnv(false);
# 			}
#
# 			self.crs = data.RegTx[0].cookies.cookie[1].value;
# 			self.tt_ut = data.RegTx[0].cookies.cookie[0].value;
#
# 			// optimizely page 1 function
# 			if (typeof successfulPage1FormSubmission === 'function') {
# 				var page1ABValue = document.getElementById("inlineRegistration_TEST---AB-Tracking1").value;
# 				successfulPage1FormSubmission(page1ABValue);
# 			}
#
# 			// Load step2
# 			executeInlineByPageAndParams("searchStorage", "inlineRegistration", "inlineregister", 7, { t:(new Date().getTime()) });
# 		}
# 		if(data.RegTx[0].validations.validation) {
#                      err();
# 		}
#
# 	}).fail(function() {
#              err();
# 	});
#
#
# };
#          </script>
#          <script>
#           window.getUtmSrcForReg = function() {
#   var decode = function(s) { return (s) ? decodeURIComponent(s.replace(/\+/g, " ")) : ""; };
#   var ret = getCookieValue("tt_src") || decode(getQueryStringValue("utm_source")) || "";
#   return ret;
# }
#          </script>
#         </div>
#        </div>
#        <p>
#         such as REST. With REST APIs, you can integrate storage management with your own scripts, which makes IT more flexible and programmable. If you're a storage admin and you want to manage resources more openly, then you need to know a little bit about using REST APIs in Python, a common scripting language.
#        </p>
#        <div class="ad-wrapper ad-embedded">
#         <div class="ad ad-hp" id="halfpage">
#          <script>
#           GPT.display('halfpage')
#          </script>
#         </div>
#         <div class="ad ad-mu" id="mu-1">
#          <script>
#           GPT.display('mu-1')
#          </script>
#         </div>
#        </div>
#        <p>
#         REST APIs provide easy access to countless web-based services. Whether you want to send a tweet, upload a document to Dropbox, create your own cloud server or access publicly available data, REST APIs underpin everything. Using these services from Python is quite easy, especially with a
#         <a href="http://www.computerweekly.com/feature/Hot-skills-Python">
#          native Python
#         </a>
#         wrapper or software development kit (SDK).
#        </p>
# ...
#     <nav class="latest-nav-wrapper">
#      <h2>
#       Latest TechTarget
#       <span class="latest-title">
#        resources
#       </span>
#      </h2>
#      <ul class="latest-nav">
#       <li>
#        <a class="latest-nav-item selected" data-item="1" href="#">
#         Disaster Recovery
#         <i class="icon mobile-icon" data-icon="5">
#         </i>
#         <i class="icon desktop-icon" data-icon="A">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a class="latest-nav-item" data-item="2" href="#">
#         Data Backup
#         <i class="icon mobile-icon" data-icon="5">
#         </i>
#         <i class="icon desktop-icon" data-icon="A">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a class="latest-nav-item" data-item="3" href="#">
#         ConvergedInfrastructure
#         <i class="icon mobile-icon" data-icon="5">
#         </i>
#         <i class="icon desktop-icon" data-icon="A">
#         </i>
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <span class="latest-nav-mask before-mask">
#     </span>
#     <span class="latest-nav-mask after-mask">
#     </span>
#     <div class="latest-body">
#      <div class="latest-content" data-item="1">
#       <h2 class="searchdisasterrecovery">
#        <a href="http://searchdisasterrecovery.techtarget.com">
#         <span class="logo-search">
#          Search
#         </span>
#         <span class="logo-1">
#          Disaster
#         </span>
#         <span class="logo-2">
#          Recovery
#         </span>
#        </a>
#       </h2>
#       <ul>
#        <li>
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchdisasterrecovery.techtarget.com/news/252434195/Arcserve-Unified-Data-Protection-cuts-downtime-for-cloud-DR">
#           Arcserve Unified Data Protection cuts downtime for cloud DR
#          </a>
#         </h3>
#         <p>
#          Arcserve UDP delivers short RPO and RTO for backup and disaster recovery in the cloud. The upgraded platform targets the ...
#         </p>
#        </li>
#        <li>
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchdisasterrecovery.techtarget.com/tip/Enhance-your-GRC-program-with-business-continuity-and-DR">
#           Enhance your GRC program with business continuity and DR
#          </a>
#         </h3>
#         <p>
#          Any governance, risk management and compliance program should work with an organization's business continuity process. There are ...
#         </p>
#        </li>
#        <li class="hide-for-small">
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchdisasterrecovery.techtarget.com/news/450432781/Frost-Science-Museum-IT-DR-planning-braced-for-worst-survived-Irma">
#           Frost Science Museum IT DR planning braced for worst, survived Irma
#          </a>
#         </h3>
#         <p>
#          The Frost Museum of Science on the water in Miami braced for Hurricane Irma with a solidified storage and data center ...
#         </p>
#        </li>
#       </ul>
#      </div>
#      <div class="latest-content" data-item="2">
#       <h2 class="searchdatabackup">
#        <a href="http://searchdatabackup.techtarget.com">
#         <span class="logo-search">
#          Search
#         </span>
#         <span class="logo-1">
#          Data
#         </span>
#         <span class="logo-2">
#          Backup
#         </span>
#        </a>
#       </h2>
#       <ul>
#        <li>
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchdatabackup.techtarget.com/tip/Build-data-storage-reliability-into-a-backup-infrastructure">
#           Build data storage reliability into a backup infrastructure
#          </a>
#         </h3>
#         <p>
#          In today's market, there are a variety of data backup options. Here's how to make sure your organization's essential data will ...
#         </p>
#        </li>
#        <li>
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchdatabackup.techtarget.com/podcast/Veeam-CEO-Peter-McKay-details-companys-plans-challenges">
#           Veeam CEO Peter McKay details company's plans, challenges
#          </a>
#         </h3>
#         <p>
#          Peter McKay, co-CEO of Veeam Software, reflects on his year and a half with the company, the evolution of the data protection ...
#         </p>
#        </li>
#        <li class="hide-for-small">
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchdatabackup.techtarget.com/tip/The-role-of-a-GDPR-data-protection-officer">
#           The role of a GDPR data protection officer
#          </a>
#         </h3>
#         <p>
#          The data protection officer, required for many organizations to be compliant with the EU's GDPR, will face challenges in the new ...
#         </p>
#        </li>
#       </ul>
#      </div>
#      <div class="latest-content" data-item="3">
#       <h2 class="searchconvergedinfrastructure">
#        <a href="http://searchconvergedinfrastructure.techtarget.com">
#         <span class="logo-search">
#          Search
#         </span>
#         <span class="logo-1">
#          Converged
#         </span>
#         <span class="logo-2">
#          Infrastructure
#         </span>
#        </a>
#       </h2>
#       <ul>
#        <li>
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchconvergedinfrastructure.techtarget.com/tip/The-impact-of-Spectre-and-Meltdown-vulnerabilities-on-storage">
#           Spectre, Meltdown vulnerabilities put SDS, HCI at risk
#          </a>
#         </h3>
#         <p>
#          Spectre and Meltdown patches should be applied to hyper-converged and other software-defined storage products that run on hosts ...
#         </p>
#        </li>
#        <li>
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchconvergedinfrastructure.techtarget.com/feature/Hypervisor-software-and-your-hyper-converged-infrastructure">
#           Hypervisor software and your hyper-converged infrastructure
#          </a>
#         </h3>
#         <p>
#          The hypervisor layer in HCI is becoming an expected feature, but it is important to know what role it plays and how it can affect...
#         </p>
#        </li>
#        <li class="hide-for-small">
#         <i class="icon" data-icon="2">
#         </i>
#         <h3>
#          <a href="http://searchconvergedinfrastructure.techtarget.com/tip/Converged-vs-hyper-converged-labels-dont-apply-to-some-products">
#           Converged vs. hyper-converged labels don't apply to some products
#          </a>
#         </h3>
#         <p>
#          Converged and hyper-converged infrastructure labels are becoming less clear as vendors such as NetApp and Datrium introduce ...
#         </p>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </section>
#    <!-- FooterLinksController, generated at 14:19:12 Fri Feb 2, 2018, by pv-ecmappma6.techtarget.com -->
#    <footer id="page-footer">
#     <div class="content-left">
#      <!-- Plug in TechTarget Logo inside the anchor tag here. -->
#      <div class="column column-logo">
#       <a href="#">
#       </a>
#      </div>
#     </div>
#     <div class="content-center">
#      <ul class="column">
#       <li class="footer-item footer-item-col-1 footer-item-row-1">
#        <a href="http://searchstorage.techtarget.com/about">
#         About Us
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-1 footer-item-row-2">
#        <a href="http://searchstorage.techtarget.com/about/editors">
#         Meet The Editors
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-1 footer-item-row-3">
#        <a href="http://searchstorage.techtarget.com/about/contact">
#         Contact Us
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-1 footer-item-row-4">
#        <a href="https://www.techtarget.com/html/privacy_policy.html">
#         Privacy Policy
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-1 footer-item-row-5">
#        <a href="http://searchstorage.techtarget.com/about/advertising">
#         Advertisers
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-1 footer-item-row-6">
#        <a href="http://searchstorage.techtarget.com/about/partners">
#         Business Partners
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-1 footer-item-row-7">
#        <a href="http://www.techtarget.com/mediakit">
#         Media Kit
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-1 footer-item-row-8">
#        <a href="https://www.techtarget.com">
#         Corporate Site
#        </a>
#       </li>
#      </ul>
#      <ul class="column">
#       <li class="footer-item footer-item-col-2 footer-item-row-1">
#        <a href="http://searchstorage.techtarget.com/contributors">
#         Contributors
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-2 footer-item-row-2">
#        <a href="http://reprints.ygsgroup.com/m/techtarget">
#         Reprints
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-2 footer-item-row-3">
#        <a href="http://searchstorage.techtarget.com/archive">
#         Archive
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-2 footer-item-row-4">
#        <a href="http://searchstorage.techtarget.com/sitemap">
#         Site Map
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-2 footer-item-row-5">
#        <a href="http://searchstorage.techtarget.com/answers">
#         Answers
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-2 footer-item-row-6">
#        <a href="http://searchstorage.techtarget.com/definitions">
#         Definitions
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-2 footer-item-row-7">
#        <a href="http://searchstorage.techtarget.com/eproducts">
#         E-Products
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-2 footer-item-row-8">
#        <a href="http://searchstorage.techtarget.com/events">
#         Events
#        </a>
#       </li>
#      </ul>
#      <ul class="column column-mobile-hidden">
#       <li class="footer-item footer-item-col-3 footer-item-row-1">
#        <a href="http://searchstorage.techtarget.com/features">
#         Features
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-3 footer-item-row-2">
#        <a href="http://searchstorage.techtarget.com/guides">
#         Guides
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-3 footer-item-row-3">
#        <a href="http://searchstorage.techtarget.com/opinions">
#         Opinions
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-3 footer-item-row-4">
#        <a href="http://searchstorage.techtarget.com/photostories">
#         Photo Stories
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-3 footer-item-row-5">
#        <a href="http://searchstorage.techtarget.com/quizzes">
#         Quizzes
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-3 footer-item-row-6">
#        <a href="http://searchstorage.techtarget.com/tips">
#         Tips
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-3 footer-item-row-7">
#        <a href="http://searchstorage.techtarget.com/tutorials">
#         Tutorials
#        </a>
#       </li>
#       <li class="footer-item footer-item-col-3 footer-item-row-8">
#        <a href="http://searchstorage.techtarget.com/videos">
#         Videos
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="content-right">
#      <div class="column column-legal">
#       <p class="footer-legal">
#        All Rights Reserved,
#        <span>
#         <a href="http://searchstorage.techtarget.com/about/copyright">
#          Copyright 2000 - 2018
#         </a>
#         , TechTarget
#        </span>
#       </p>
#      </div>
#     </div>
#    </footer>
#    <script src="https://cdn.ttgtmedia.com/rms/ux/responsive/js/responsive-ui.min.js?v=7.1">
#    </script>
#    <!-- Begin Chartbeat -->
#    <script>
#     var _sf_async_config={};
#     _sf_async_config.uid = 41935;
#     _sf_async_config.domain = 'techtargetnetwork.com';
#     _sf_async_config.sections = 'sstr, sstr - Cloud storage';
#     _sf_async_config.authors = 'G\u00E1bor Nyers, TIPS, sstr - TIPS';
#     _sf_async_config.useCanonical = true;
#     (function(){
#       function loadChartbeat() {
#         window._sf_endpt=(new Date()).getTime();
#         var e = document.createElement('script');
#         e.setAttribute('language', 'javascript');
#         e.setAttribute('type', 'text/javascript');
#         e.setAttribute('src',
#            (('https:' == document.location.protocol) ? 'https://a248.e.akamai.net/chartbeat.download.akamai.com/102508/' : 'https://static.chartbeat.com/') + 'js/chartbeat.js');
#         document.body.appendChild(e);
#       }
#       var oldonload = window.onload;
#       window.onload = (typeof window.onload != 'function') ?
#          loadChartbeat : function() { oldonload(); loadChartbeat(); };
#     })();
#    </script>
#    <!-- End Chartbeat -->
#    <!-- Begin DataPoint Media -->
#    <script>
#     (function() {
# var d=document,h=d.getElementsByTagName('head')[0],s=d.createElement('script'),sc = 'https:' == document.location.protocol ? 'https://' : 'http://';
# s.type='text/javascript';
# s.async=true;
# s.src=sc+'s.dpmsrv.com/dpm_b4c96d80854dd27e76d8cc9e21960eebda52e962.min.js';
# h.appendChild(s);
# })();
#    </script>
#    <!-- End DataPoint Media -->
#    <!-- Begin CrazyEgg -->
#    <script>
#     setTimeout(function(){
# var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//dnn506yrbagrg.cloudfront.net/pages/scripts/0012/7034.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;
# a.type="text/javascript";
# b.parentNode.insertBefore(a,b)
# }, 1);
#    </script>
#    <!-- End CrazyEgg -->
#    <!-- Begin GoogleRemarketing -->
#    <script>
#     var google_conversion_id = 1070110249;
# var google_conversion_label = "RRsgCOW4tgMQqayi_gM";
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
#    </script>
#    <script src="https://www.googleadservices.com/pagead/conversion.js">
#    </script>
#    <noscript>
#     <div style="display:inline;">
#      <img alt="" height="1" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1070110249/?value=0&amp;label=RRsgCOW4tgMQqayi_gM&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#     </div>
#    </noscript>
#    <script>
#     var google_conversion_id = 1072226410;
# var google_conversion_label = "x3P_CIql1gMQ6sCj_wM";
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
#    </script>
#    <script src="https://www.googleadservices.com/pagead/conversion.js">
#    </script>
#    <noscript>
#     <div style="display:inline;">
#      <img alt="" height="1" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1072226410/?value=0&amp;label=x3P_CIql1gMQ6sCj_wM&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#     </div>
#    </noscript>
#    <!-- End GoogleRemarketing -->
#   </div>
#   <div class="mobile-sidebars" id="mobile-sidebars">
#   </div>
#   <div class="image-overlay" id="image-overlay">
#    <div class="image-overlay-img">
#    </div>
#    <div class="image-overlay-close">
#     Close
#    </div>
#   </div>
#   <!--
# Component Load Times
# ====================
# DefaultPageController=42 ms
# PinnedNavBarController=48 ms
# AdsController=0 ms
# ContentItemController=78 ms
# RefineryController=0 ms
# RelatedContentController=32 ms
# VendorResourcesController=79 ms
# EzinePromoController=3 ms
# DigDeeperController=99 ms
# ProFeaturesController=10 ms
# DiscussionsController=4 ms
# AskAnExpertController=0 ms
# HaveAQuestionForAnExpertController=0 ms
# CommentingController=8 ms
#
# Total time=403 ms
# Request Serving Server: pv-ecmappma6.techtarget.com
# -->
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam.nr-data.net","licenseKey":"1068cf12f6","agent":"","beacon":"bam.nr-data.net","applicationTime":613,"applicationID":"313780","transactionName":"ZQMAYxdYXUBSAkFbClxJN0UMFhkcRwhFHU8=","queueTime":0}
#   </script>
#  </body>
# </html>

# %%
#Collect all of the external links 
links = soup.find_all('a')
links_http=[]
for each in links:
    if str(each.get('href'))[:4]=='http':  
        links_http.append(each)  
links_http
# Out:
# [<a class="header-logo mobile-link" href="http://www.techtarget.com/network">
#  <span class="header-logo-mobile">SearchStorage</span>
#  </a>,
#  <a class="header-logo desktop-link" href="http://searchstorage.techtarget.com">
#  <img alt="TechTarget" class="header-logo-desktop replace_2x" src="https://cdn.ttgtmedia.com/rms/ux/responsive/img/nav_logo.png"/>
#  <img alt="TechTarget" class="header-logo-small replace_2x" src="https://cdn.ttgtmedia.com/rms/ux/responsive/img/nav_logo.png"/>
#  </a>,
#  <a class="nav-join-pro" href="https://users.techtarget.com/registration/searchStorage/LoginRegister.page"><span>Sign-up now. Start my free, unlimited access.</span></a>,
#  <a href="https://users.techtarget.com/registration/searchStorage/LoginRegister.page"><span class="nav-user-action">Login</span></a>,
#  <a class="register" href="https://users.techtarget.com/registration/searchStorage/Register.page"><span class="nav-user-action">Register</span></a>,
#  <a href="http://www.techtarget.com/network">Techtarget Network</a>,
#  <a href="http://searchstorage.techtarget.com/info/news">News</a>,
#  <a href="http://searchstorage.techtarget.com/features">Features</a>,
#  <a href="http://searchstorage.techtarget.com/tips">Tips</a>,
#  <a href="http://searchstorage.techtarget.com/answers">Answers</a>,
#  <a href="http://whatis.techtarget.com/resources/Buyers-Guides">Buyer's Guides</a>,
#  <a href="http://searchstorage.techtarget.com/definitions">Definitions</a>,
#  <a href="http://searchstorage.techtarget.com/guides">Essential Guides</a>,
#  <a href="http://searchstorage.techtarget.com/opinions">Opinions</a>,
#  <a href="http://searchstorage.techtarget.com/photostories">Photo Stories</a>,
#  <a href="http://searchstorage.techtarget.com/podcasts">Podcasts</a>,
#  <a href="http://searchstorage.techtarget.com/quizzes">Quizzes</a>,
#  <a href="http://searchstorage.techtarget.com/tutorials">Tutorials</a>,
#  <a href="http://searchstorage.techtarget.com/sponsored_communities">Sponsored Communities</a>,
#  <a href="http://searchstorage.techtarget.com/blog/Storage-Soup">Storage Soup Blog</a>,
#  <a href="http://searchstorage.techtarget.com">
#  <span class="nav-list-item-header-title">
#  <span class="logo-search">Search</span><span class="logo-1">Storage</span></span>
#  </a>,
#  <a href="http://searchstorage.techtarget.com/resources/Cloud-Storage">
#  								Cloud storage</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Application-storage"> Application storage</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Flash-memory"> Flash memory</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Object-storage"> Object storage</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Primary-storage-devices"> Primary storage  devices</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Software-defined-storage"> Software-defined storage</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Solid-State-Storage"> Solid-state storage</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Storage-management-and-analytics"> Storage management and analytics</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Storage-market-research-reports"> Storage market research reports</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Storage-vendors"> Storage vendors</a>,
#  <a href="http://searchstorage.techtarget.com/resources">All Topics</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Cloud-storage-management-and-standards"> Cloud storage management and standards</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Cloud-storage-gateways"> Cloud storage gateways</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Cloud-storage-management-and-standards"> Cloud storage management and standards</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Hybrid-cloud-storage"> Hybrid cloud storage</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Private-Cloud-Storage"> Private cloud</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Public-Cloud-Storage"> Public cloud</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Cloud-Storage">All Subtopics</a>,
#  <a href="https://plus.google.com/u/0/106000202575757202315" target="_blank"><i class="icon" data-icon="s"></i></a>,
#  <a href="https://www.facebook.com/Search-Storage/10150115721885374" target="_blank"><i class="icon" data-icon="u"></i></a>,
#  <a href="https://twitter.com/searchstoragett" target="_blank"><i class="icon" data-icon="c"></i></a>,
#  <a href="http://www.linkedin.com/company/3007485?trk=tyah" target="_blank"><i class="icon" data-icon="o"></i></a>,
#  <a class="infotype-eyebrow-link" href="http://searchstorage.techtarget.com/info/getstarted">Get started</a>,
#  <a href="http://searchaws.techtarget.com/tip/Boto-gains-foothold-as-AWS-SDK-for-Python-standard">Boto gains foothold as AWS SDK for Python standard</a>,
#  <a href="http://searchaws.techtarget.com/definition/Boto">Boto</a>,
#  <a href="http://searchaws.techtarget.com/tip/AWS-SDKs-match-services-to-language-platform">AWS SDKs match services to language, platform</a>,
#  <a href="http://www.convergedinfrastructure.com/The-Lowdown-on-Software-Defined-Storage-in-the-Data-Center?asrc=SS_sstr_SN-450433401">The Lowdown on Software-Defined Storage in the Data Center</a>,
#  <a href="http://searchstorage.techtarget.com/hyperconvergedspotlight/One-More-Reason-to-Use-HCI-Bolstering-Security?asrc=SS_sstr_SN-450433401">One More Reason to Use HCI: Bolstering Security</a>,
#  <a href="http://searchstorage.techtarget.com/sponsored_communities">See More</a>,
#  <a href="https://www.bitpipe.com/detail/RES/1515782281_21.html">A Hybrid Cloud Approach To Big Data In The Enterprise</a>,
#  <a href="https://users.techtarget.com/registration/searchstorage/LoginRegister">Sign in for existing members</a>,
#  <a class="inlineRegLoginErrMsg" href="https://users.techtarget.com/registration/searchstorage/LoginRegister">login</a>,
#  <a class="consentWindow" href="https://users.techtarget.com/registration/searchStorage/DisplayConsentText.page?languageCd=en&amp;enText=true">Declaration of Consent.</a>,
#  <a href="http://www.techtarget.com/html/privacy_partners_0-c.html" target="_blank">partners</a>,
#  <a href="http://searchstorage.techtarget.com/about/copyright" target="_blank">Terms of Use</a>,
#  <a href="http://www.techtarget.com/html/privacy_policy.html" target="_blank">Privacy Policy</a>,
#  <a href="http://www.computerweekly.com/feature/Hot-skills-Python">native Python</a>,
#  <a href="http://searchmicroservices.techtarget.com/tip/Support-for-RESTful-Web-Services-Part-1">specify an action and an endpoint</a>,
#  <a href="http://searchsoftwarequality.techtarget.com/tip/Why-use-POST-vs-GET-to-keep-applications-secure">PUT or POST method</a>,
#  <a href="http://searchaws.techtarget.com/definition/Boto">Python SDK provided by Amazon</a>,
#  <a href="http://searchsecurity.techtarget.com/tip/Why-authorization-management-is-paramount-for-cybersecurity-readiness">authentication and authorization scheme</a>,
#  <a href="http://searchaws.techtarget.com/feature/Book-excerpt-AWS-S3-tutorial-for-newbies">AWS S3 services</a>,
#  <a href="https://wiki.python.org/moin/DocumentationTools" target="_blank">output produced</a>,
#  <a href="http://searchstorage.techtarget.com/archive/2018/1">January 2018</a>,
#  <a href="http://searchstorage.techtarget.com/news/450431845/Misconfigured-Amazon-S3-buckets-expose-sensitive-data">Misconfigured Amazon S3 buckets expose sensitive data</a>,
#  <a href="http://searchstorage.techtarget.com/definition/cloud-data-management">cloud data management</a>,
#  <a href="http://searchstorage.techtarget.com/definition/Cinder-OpenStack-Block-Storage">OpenStack Block Storage (Cinder)</a>,
#  <a href="http://searchstorage.techtarget.com/feature/Businesses-use-enterprise-file-sync-and-share-market-to-collaborate">Businesses use enterprise file sync-and-share market to collaborate</a>,
#  <a href="http://searchstorage.techtarget.com/resources/Cloud-storage-management-and-standards">
#  <button class="button black-button dig-deeper-load-more" id="digDeeperViewAll">
#  										View All</button>
#  </a>,
#  <a href="http://searchstorage.techtarget.com/news/450431845/Misconfigured-Amazon-S3-buckets-expose-sensitive-data">Misconfigured Amazon S3 buckets expose sensitive data</a>,
#  <a href="http://searchstorage.techtarget.com/feature/Businesses-use-enterprise-file-sync-and-share-market-to-collaborate">Businesses use enterprise file sync-and-share market to collaborate</a>,
#  <a href="http://searchstorage.techtarget.com/opinion/Showback-the-value-of-your-data-storage-expertise">Showback the value of your data storage expertise</a>,
#  <a href="http://searchstorage.techtarget.com/news/450403064/Hitachi-Content-Intelligence-searches-analyzes-data">Hitachi Content Intelligence searches, analyzes data</a>,
#  <a href="http://searchstorage.techtarget.com/info/news/Cloud-storage-management-and-standards">
#  <button class="button black-button dig-deeper-load-more" id="digDeeperViewAll_news_infotype">
#  										View All News</button>
#  </a>,
#  <a href="http://searchstorage.techtarget.com/definition/cloud-data-management">cloud data management</a>,
#  <a href="http://searchstorage.techtarget.com/definition/Cinder-OpenStack-Block-Storage">OpenStack Block Storage (Cinder)</a>,
#  <a href="http://searchstorage.techtarget.com/definition/Zadara-VPSA-and-ZIOS">Zadara VPSA and ZIOS</a>,
#  <a href="http://searchstorage.techtarget.com/definition/pay-as-you-grow-pricing">pay-as-you-grow pricing</a>,
#  <a href="http://searchstorage.techtarget.com/info/getstarted/Cloud-storage-management-and-standards">
#  <button class="button black-button dig-deeper-load-more" id="digDeeperViewAll_get_started_infotype">
#  										View All Get started</button>
#  </a>,
#  <a href="http://searchstorage.techtarget.com/feature/Businesses-use-enterprise-file-sync-and-share-market-to-collaborate">Businesses use enterprise file sync-and-share market to collaborate</a>,
#  <a href="http://searchstorage.techtarget.com/opinion/With-on-premises-storage-storage-administrators-must-adapt-or-perish">With on-premises storage, storage administrators must adapt or perish</a>,
#  <a href="http://searchstorage.techtarget.com/tip/Why-a-cloud-storage-architecture-is-a-good-virtual-server-option">Why a cloud storage architecture is a good virtual server option</a>,
#  <a href="http://searchstorage.techtarget.com/opinion/Its-time-to-redefine-the-enterprise-file-sync-and-share-market">It's time to redefine the enterprise file sync-and-share market</a>,
#  <a href="http://searchstorage.techtarget.com/info/evaluate/Cloud-storage-management-and-standards">
#  <button class="button black-button dig-deeper-load-more" id="digDeeperViewAll_evaluate_infotype">
#  										View All Evaluate</button>
#  </a>,
#  <a href="http://searchstorage.techtarget.com/opinion/Showback-the-value-of-your-data-storage-expertise">Showback the value of your data storage expertise</a>,
#  <a href="http://searchstorage.techtarget.com/feature/Understand-enterprise-file-sync-and-share-deployment-models">Understand enterprise file sync-and-share deployment models</a>,
#  <a href="http://searchstorage.techtarget.com/answer/What-are-the-best-ways-to-manage-multiple-cloud-providers">What are the best ways to manage multiple cloud providers?</a>,
#  <a href="http://searchstorage.techtarget.com/essentialguide/The-case-for-cloud-storage-Cloud-considerations-and-strategies">The case for cloud storage: Cloud considerations and strategies</a>,
#  <a href="http://searchstorage.techtarget.com/info/manage/Cloud-storage-management-and-standards">
#  <button class="button black-button dig-deeper-load-more" id="digDeeperViewAll_manage_infotype">
#  										View All Manage</button>
#  </a>,
#  <a href="http://searchstorage.techtarget.com/answer/How-can-I-ensure-peak-cloud-storage-performance">How can I ensure peak cloud storage performance?</a>,
#  <a href="http://searchstorage.techtarget.com/answer/Can-storage-hypervisors-bring-high-availability-to-the-cloud">Can storage hypervisors bring high availability to the cloud?</a>,
#  <a href="http://searchstorage.techtarget.com/tip/Eight-questions-to-ask-before-using-cloud-storage">Eight questions to ask before using cloud storage</a>,
#  <a href="http://searchstorage.techtarget.com/tip/Cloud-based-archiving-Is-it-right-for-your-environment">Cloud-based archiving: Is it right for your environment?</a>,
#  <a href="http://searchstorage.techtarget.com/info/problemsolve/Cloud-storage-management-and-standards">
#  <button class="button black-button dig-deeper-load-more" id="digDeeperViewAll_problem_solve_infotype">
#  										View All Problem solve</button>
#  </a>,
#  <a href="http://pro.techtarget.com/ProLP?Offer=PROContentBox">here.</a>,
#  <a href="http://searchstorage.techtarget.com/ezine/Storage-magazine/Storage-startup-trends-Vendors-to-watch-in-2018">Storage startup trends: Vendors to watch in 2018</a>,
#  <a href="http://searchstorage.techtarget.com/ezine/Storage-magazine/The-hottest-data-storage-technology-trends-for-2018">The hottest data storage technology trends for 2018</a>,
#  <a href="http://searchstorage.techtarget.com/ehandbook/Manage-multiple-clouds-for-security-and-strong-data-backup">Manage multiple clouds for security and strong data backup</a>,
#  <a href="http://www.techtarget.com/html/privacy_policy.html">Privacy</a>,
#  <a href="https://www.google.com/adsense/support/bin/request.py?contact=abg_afc">-ADS BY GOOGLE</a>,
#  <a href="http://searchdisasterrecovery.techtarget.com">
#  <span class="logo-search">Search</span><span class="logo-1">Disaster</span><span class="logo-2">Recovery</span></a>,
#  <a href="http://searchdisasterrecovery.techtarget.com/news/252434195/Arcserve-Unified-Data-Protection-cuts-downtime-for-cloud-DR">Arcserve Unified Data Protection cuts downtime for cloud DR</a>,
#  <a href="http://searchdisasterrecovery.techtarget.com/tip/Enhance-your-GRC-program-with-business-continuity-and-DR">Enhance your GRC program with business continuity and DR</a>,
#  <a href="http://searchdisasterrecovery.techtarget.com/news/450432781/Frost-Science-Museum-IT-DR-planning-braced-for-worst-survived-Irma">Frost Science Museum IT DR planning braced for worst, survived Irma</a>,
#  <a href="http://searchdatabackup.techtarget.com">
#  <span class="logo-search">Search</span><span class="logo-1">Data</span><span class="logo-2">Backup</span></a>,
#  <a href="http://searchdatabackup.techtarget.com/tip/Build-data-storage-reliability-into-a-backup-infrastructure">Build data storage reliability into a backup infrastructure</a>,
#  <a href="http://searchdatabackup.techtarget.com/podcast/Veeam-CEO-Peter-McKay-details-companys-plans-challenges">Veeam CEO Peter McKay details company's plans, challenges</a>,
#  <a href="http://searchdatabackup.techtarget.com/tip/The-role-of-a-GDPR-data-protection-officer">The role of a GDPR data protection officer</a>,
#  <a href="http://searchconvergedinfrastructure.techtarget.com">
#  <span class="logo-search">Search</span><span class="logo-1">Converged</span><span class="logo-2">Infrastructure</span></a>,
#  <a href="http://searchconvergedinfrastructure.techtarget.com/tip/The-impact-of-Spectre-and-Meltdown-vulnerabilities-on-storage">Spectre, Meltdown vulnerabilities put SDS, HCI at risk</a>,
#  <a href="http://searchconvergedinfrastructure.techtarget.com/feature/Hypervisor-software-and-your-hyper-converged-infrastructure">Hypervisor software and your hyper-converged infrastructure</a>,
#  <a href="http://searchconvergedinfrastructure.techtarget.com/tip/Converged-vs-hyper-converged-labels-dont-apply-to-some-products">Converged vs. hyper-converged labels don't apply to some products</a>,
#  <a href="http://searchstorage.techtarget.com/about">About Us</a>,
#  <a href="http://searchstorage.techtarget.com/about/editors">Meet The Editors</a>,
#  <a href="http://searchstorage.techtarget.com/about/contact">Contact Us</a>,
#  <a href="https://www.techtarget.com/html/privacy_policy.html">Privacy Policy</a>,
#  <a href="http://searchstorage.techtarget.com/about/advertising">Advertisers</a>,
#  <a href="http://searchstorage.techtarget.com/about/partners">Business Partners</a>,
#  <a href="http://www.techtarget.com/mediakit">Media Kit</a>,
#  <a href="https://www.techtarget.com">Corporate Site</a>,
#  <a href="http://searchstorage.techtarget.com/contributors">Contributors</a>,
#  <a href="http://reprints.ygsgroup.com/m/techtarget">Reprints</a>,
#  <a href="http://searchstorage.techtarget.com/archive">Archive</a>,
#  <a href="http://searchstorage.techtarget.com/sitemap">Site Map</a>,
#  <a href="http://searchstorage.techtarget.com/answers">Answers</a>,
#  <a href="http://searchstorage.techtarget.com/definitions">Definitions</a>,
#  <a href="http://searchstorage.techtarget.com/eproducts">E-Products</a>,
#  <a href="http://searchstorage.techtarget.com/events">Events</a>,
#  <a href="http://searchstorage.techtarget.com/features">Features</a>,
#  <a href="http://searchstorage.techtarget.com/guides">Guides</a>,
#  <a href="http://searchstorage.techtarget.com/opinions">Opinions</a>,
#  <a href="http://searchstorage.techtarget.com/photostories">Photo Stories</a>,
#  <a href="http://searchstorage.techtarget.com/quizzes">Quizzes</a>,
#  <a href="http://searchstorage.techtarget.com/tips">Tips</a>,
#  <a href="http://searchstorage.techtarget.com/tutorials">Tutorials</a>,
#  <a href="http://searchstorage.techtarget.com/videos">Videos</a>,
#  <a href="http://searchstorage.techtarget.com/about/copyright">Copyright 2000 - 2018</a>]

# %%
# text of link
links_http_text = []
for link in links_http:
    links_http_text.append(link.text)
links_http_text
# Out:
# ['\nSearchStorage\n',
#  '\n\n\n',
#  'Sign-up now. Start my free, unlimited access.',
#  'Login',
#  'Register',
#  'Techtarget Network',
#  'News',
#  'Features',
#  'Tips',
#  'Answers',
#  "Buyer's Guides",
#  'Definitions',
#  'Essential Guides',
#  'Opinions',
#  'Photo Stories',
#  'Podcasts',
#  'Quizzes',
#  'Tutorials',
#  'Sponsored Communities',
#  'Storage Soup Blog',
#  '\n\nSearchStorage\n',
#  '\n\t\t\t\t\t\t\t\tCloud storage',
#  ' Application storage',
#  ' Flash memory',
#  ' Object storage',
#  ' Primary storage  devices',
#  ' Software-defined storage',
#  ' Solid-state storage',
#  ' Storage management and analytics',
#  ' Storage market research reports',
#  ' Storage vendors',
#  'All Topics',
#  ' Cloud storage management and standards',
#  ' Cloud storage gateways',
#  ' Cloud storage management and standards',
#  ' Hybrid cloud storage',
#  ' Private cloud',
#  ' Public cloud',
#  'All Subtopics',
#  '',
#  '',
#  '',
#  '',
#  'Get started',
#  'Boto gains foothold as AWS SDK for Python standard',
#  'Boto',
#  'AWS SDKs match services to language, platform',
#  'The Lowdown on Software-Defined Storage in the Data Center',
#  'One More Reason to Use HCI: Bolstering Security',
#  'See More',
#  'A Hybrid Cloud Approach To Big Data In The Enterprise',
#  'Sign in for existing members',
#  'login',
#  'Declaration of Consent.',
#  'partners',
#  'Terms of Use',
#  'Privacy Policy',
#  'native Python',
#  'specify an action and an endpoint',
#  'PUT or POST method',
#  'Python SDK provided by Amazon',
#  'authentication and authorization scheme',
#  'AWS S3 services',
#  'output produced',
#  'January 2018',
#  'Misconfigured Amazon S3 buckets expose sensitive data',
#  'cloud data management',
#  'OpenStack Block Storage (Cinder)',
#  'Businesses use enterprise file sync-and-share market to collaborate',
#  '\n\n\t\t\t\t\t\t\t\t\t\tView All\n',
#  'Misconfigured Amazon S3 buckets expose sensitive data',
#  'Businesses use enterprise file sync-and-share market to collaborate',
#  'Showback the value of your data storage expertise',
#  'Hitachi Content Intelligence searches, analyzes data',
#  '\n\n\t\t\t\t\t\t\t\t\t\tView All News\n',
#  'cloud data management',
#  'OpenStack Block Storage (Cinder)',
#  'Zadara VPSA and ZIOS',
#  'pay-as-you-grow pricing',
#  '\n\n\t\t\t\t\t\t\t\t\t\tView All Get started\n',
#  'Businesses use enterprise file sync-and-share market to collaborate',
#  'With on-premises storage, storage administrators must adapt or perish',
#  'Why a cloud storage architecture is a good virtual server option',
#  "It's time to redefine the enterprise file sync-and-share market",
#  '\n\n\t\t\t\t\t\t\t\t\t\tView All Evaluate\n',
#  'Showback the value of your data storage expertise',
#  'Understand enterprise file sync-and-share deployment models',
#  'What are the best ways to manage multiple cloud providers?',
#  'The case for cloud storage: Cloud considerations and strategies',
#  '\n\n\t\t\t\t\t\t\t\t\t\tView All Manage\n',
#  'How can I ensure peak cloud storage performance?',
#  'Can storage hypervisors bring high availability to the cloud?',
#  'Eight questions to ask before using cloud storage',
#  'Cloud-based archiving: Is it right for your environment?',
#  '\n\n\t\t\t\t\t\t\t\t\t\tView All Problem solve\n',
#  'here.',
#  'Storage startup trends: Vendors to watch in 2018',
#  'The hottest data storage technology trends for 2018',
#  'Manage multiple clouds for security and strong data backup',
#  'Privacy',
#  '-ADS BY GOOGLE',
#  '\nSearchDisasterRecovery',
#  'Arcserve Unified Data Protection cuts downtime for cloud DR',
#  'Enhance your GRC program with business continuity and DR',
#  'Frost Science Museum IT DR planning braced for worst, survived Irma',
#  '\nSearchDataBackup',
#  'Build data storage reliability into a backup infrastructure',
#  "Veeam CEO Peter McKay details company's plans, challenges",
#  'The role of a GDPR data protection officer',
#  '\nSearchConvergedInfrastructure',
#  'Spectre, Meltdown vulnerabilities put SDS, HCI at risk',
#  'Hypervisor software and your hyper-converged infrastructure',
#  "Converged vs. hyper-converged labels don't apply to some products",
#  'About Us',
#  'Meet The Editors',
#  'Contact Us',
#  'Privacy Policy',
#  'Advertisers',
#  'Business Partners',
#  'Media Kit',
#  'Corporate Site',
#  'Contributors',
#  'Reprints',
#  'Archive',
#  'Site Map',
#  'Answers',
#  'Definitions',
#  'E-Products',
#  'Events',
#  'Features',
#  'Guides',
#  'Opinions',
#  'Photo Stories',
#  'Quizzes',
#  'Tips',
#  'Tutorials',
#  'Videos',
#  'Copyright 2000 - 2018']

# %%
# function to check whether a link is valid
def link_status(url):
    if str(url)[:4]=='http': 
        if  http.request('GET',url).status == 200:
            return True
        else:
            return False

# %%
temp={}
temp['a'] = 5

temp
# Out:
# {'a': 5}

# %%
# create a dict to store data
import datetime
link_data = []
for link in links_http:
    temp={}
#     temp.append(link['href'])
    temp['URL'] = link['href']
#     temp.append(link.text)
    temp['Text'] = link.text
#     temp.append(link_status(link['href']))
    temp['Valid'] = link_status(link['href'])
#     temp.append(datetime.datetime.now().strftime("%m-%d, %Y, %I:%M %p"))
    temp['Datetime'] = datetime.datetime.now().strftime("%m-%d, %Y, %I:%M %p")
    print(temp)
    link_data.append(temp)
link_data
# Out:
# {'URL': 'http://www.techtarget.com/network', 'Text': '\nSearchStorage\n', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com', 'Text': '\n\n\n', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://users.techtarget.com/registration/searchStorage/LoginRegister.page', 'Text': 'Sign-up now. Start my free, unlimited access.', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://users.techtarget.com/registration/searchStorage/LoginRegister.page', 'Text': 'Login', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://users.techtarget.com/registration/searchStorage/Register.page', 'Text': 'Register', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://www.techtarget.com/network', 'Text': 'Techtarget Network', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/info/news', 'Text': 'News', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/features', 'Text': 'Features', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/tips', 'Text': 'Tips', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/answers', 'Text': 'Answers', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://whatis.techtarget.com/resources/Buyers-Guides', 'Text': "Buyer's Guides", 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/definitions', 'Text': 'Definitions', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/guides', 'Text': 'Essential Guides', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/opinions', 'Text': 'Opinions', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/photostories', 'Text': 'Photo Stories', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/podcasts', 'Text': 'Podcasts', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/quizzes', 'Text': 'Quizzes', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/tutorials', 'Text': 'Tutorials', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/sponsored_communities', 'Text': 'Sponsored Communities', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/blog/Storage-Soup', 'Text': 'Storage Soup Blog', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com', 'Text': '\n\nSearchStorage\n', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Cloud-Storage', 'Text': '\n\t\t\t\t\t\t\t\tCloud storage', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Application-storage', 'Text': ' Application storage', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Flash-memory', 'Text': ' Flash memory', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Object-storage', 'Text': ' Object storage', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Primary-storage-devices', 'Text': ' Primary storage  devices', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Software-defined-storage', 'Text': ' Software-defined storage', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Solid-State-Storage', 'Text': ' Solid-state storage', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Storage-management-and-analytics', 'Text': ' Storage management and analytics', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Storage-market-research-reports', 'Text': ' Storage market research reports', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Storage-vendors', 'Text': ' Storage vendors', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources', 'Text': 'All Topics', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Cloud-storage-management-and-standards', 'Text': ' Cloud storage management and standards', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Cloud-storage-gateways', 'Text': ' Cloud storage gateways', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Cloud-storage-management-and-standards', 'Text': ' Cloud storage management and standards', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Hybrid-cloud-storage', 'Text': ' Hybrid cloud storage', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Private-Cloud-Storage', 'Text': ' Private cloud', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Public-Cloud-Storage', 'Text': ' Public cloud', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/resources/Cloud-Storage', 'Text': 'All Subtopics', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://plus.google.com/u/0/106000202575757202315', 'Text': '', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://www.facebook.com/Search-Storage/10150115721885374', 'Text': '', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://twitter.com/searchstoragett', 'Text': '', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://www.linkedin.com/company/3007485?trk=tyah', 'Text': '', 'Valid': False, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/info/getstarted', 'Text': 'Get started', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchaws.techtarget.com/tip/Boto-gains-foothold-as-AWS-SDK-for-Python-standard', 'Text': 'Boto gains foothold as AWS SDK for Python standard', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchaws.techtarget.com/definition/Boto', 'Text': 'Boto', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchaws.techtarget.com/tip/AWS-SDKs-match-services-to-language-platform', 'Text': 'AWS SDKs match services to language, platform', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://www.convergedinfrastructure.com/The-Lowdown-on-Software-Defined-Storage-in-the-Data-Center?asrc=SS_sstr_SN-450433401', 'Text': 'The Lowdown on Software-Defined Storage in the Data Center', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/hyperconvergedspotlight/One-More-Reason-to-Use-HCI-Bolstering-Security?asrc=SS_sstr_SN-450433401', 'Text': 'One More Reason to Use HCI: Bolstering Security', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/sponsored_communities', 'Text': 'See More', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://www.bitpipe.com/detail/RES/1515782281_21.html', 'Text': 'A Hybrid Cloud Approach To Big Data In The Enterprise', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://users.techtarget.com/registration/searchstorage/LoginRegister', 'Text': 'Sign in for existing members', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://users.techtarget.com/registration/searchstorage/LoginRegister', 'Text': 'login', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'https://users.techtarget.com/registration/searchStorage/DisplayConsentText.page?languageCd=en&enText=true', 'Text': 'Declaration of Consent.', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://www.techtarget.com/html/privacy_partners_0-c.html', 'Text': 'partners', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}
# {'URL': 'http://searchstorage.techtarget.com/about/copyright', 'Text': 'Terms of Use', 'Valid': True, 'Datetime': '02-02, 2018, 02:19 PM'}

# %%
# output an csv file
import csv
# newline='', 使输出的excel没有多余空行
with open('output.csv', 'w',encoding='utf8',newline='') as csvfile:
    fieldnames = ['URL','Text','Valid','Datetime']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for each in link_data:
        writer.writerow(each)
